# %% [markdown]
# ![image.png](https://i.imgur.com/1WaY7aA.png)
#
# ---
#
#
#
# ---

# %% [markdown]
# #  Data Science and AI
# ## Lab 9.2: Web Scraping
# INSTRUCTIONS:
# - Read the guides and hints then create the necessary analysis and code to find an answer and conclusion for the task below.

# %% [markdown]
# # Web Scraping in Python (using BeautifulSoup)
#
# ## Scraping Rules
# 1. **Always** check a website’s **Terms and Conditions** before you scrape it. Be careful to read the statements about legal use of data. Usually, the retrieved data should not be used for commercial purposes.
# 2. **Do not** request data from the website too aggressively with a program (also known as spamming), as this may break the website. Make sure the program behaves in a reasonable manner (i.e. acts like a human). One request for one webpage per second is good practice.
# 3. The layout of a website may change from time to time, so make sure to revisit the site and rewrite the code as needed

# %% [markdown]
# ## Find a Page
# Visit the [Fandom](http://fandom.wikia.com) website, find a wikia of your interest and pick a page to work with.

# %% [markdown]
# Open a web page with the browser and inspect it.
#
# Hover the cursor on the text and follow the shaded box surrounding the main text.
#
# From the result, check the main text inside a few levels of HTML tags.

# %%
## Import Libraries
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ### Define the content to retrieve (webpage's URL)

# %%
url = 'https://gameofthrones.fandom.com/wiki/Game_of_Thrones_Wiki'

# %% [markdown]
# ### Retrieve the page
# - Require Internet connection

# %%
def is_good_response(resp):
    """
    Ensures that the response is a html object.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 and 
            content_type is not None 
            and content_type.find('html') > -1)


def get_content(url):
    with closing(get(url)) as resp:
        if is_good_response(resp):
            print ("Success: ",url)
            return resp.content
        else:
            # Unable to get the url response
            return None

# %% [markdown]
# ### Convert the stream of bytes into a BeautifulSoup representation

# %%
content = get_content(url)
soup = BeautifulSoup(content, 'html.parser')
# Out:
# Success:  https://gameofthrones.fandom.com/wiki/Game_of_Thrones_Wiki

# %% [markdown]
# ### Check the content
# - The HTML source
# - Includes all tags and scripts
# - Can be long!

# %%
print (soup.prettify()[:1000])
# Out:
# <!DOCTYPE doctype html>
# <html class="" dir="ltr" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, user-scalable=yes" name="viewport"/>
#   <meta content="MediaWiki 1.19.24" name="generator">
#    <meta content="Game of Thrones Wiki,gameofthrones,Game of Thrones Wiki,Special Report: Max Borenstein prequel leaks to Game of Thrones Wiki,Game of Thrones prequel projects,Game of Thrones: The Long Night,Rhaegar Targaryen,Wight Hunt,Daenerys Targaryen's war for Westeros,Great War,Timeline,Dragonpit,King's Landing" name="keywords">
#     <meta content="...an encyclopedic guide to the HBO television series Game of Thrones that anyone can edit. Our content is up to date with the latest aired episode so beware of unwanted plot details if you are not. &amp;quot;Empire of Ash&amp;quot; Report on Max Borenstein's prequel TV series about the Doom of Valyria leaks to..." name="description"/>
#     <meta content="summary" name="twitt

# %% [markdown]
# ### Check the HTML's Title

# %%
soup.find('title').text
# Out:
# 'Game of Thrones Wiki | FANDOM powered by Wikia'

# %% [markdown]
# ### Find the main content
# - Check if it is possible to use only the relevant data

# %%
tag = 'article'
article = soup.find_all(tag)[0]

# %% [markdown]
# ### Get some of the text
# - Plain text without HTML tags

# %%
print (len(article.text))
# Out:
# 9219

# %%
print(re.sub(r'\n\n+', '\n', article.text)[:500])
# Out:
# 									window.adslots2.push(["top_boxad"]);
#
# ...an encyclopedic guide to the HBO television series Game of Thrones that anyone can edit. Our content is up to date with the latest aired episode so beware of unwanted plot details if you are not.
# Jon
# Sansa
# Arya
# Bran
# Brienne
# Daenerys
# Tyrion
# Missandei
# Grey Worm
# Jorah
# Cersei
# Jaime
# Bronn
# Gregor
# Qyburn
# Euron
# Yara
# Theon
# Davos
# Gendry
# Varys
# Samwell
# Tormund
# Sandor
# Melisandre
# "Empire of Ash"
# Report on Max Borenstein's prequel TV series about the Do

# %% [markdown]
# ### Find the links in the text

# %%
# identify the type of tag to retrieve
tag = 'a'
# create a list with the links from the `<a>` tag
links = [t.get('href') for t in article.find_all(tag)]
print('Number of links:', len(links))
links
# Out:
# Number of links: 537
# ['/wiki/HBO',
#  '/wiki/Game_of_Thrones',
#  '/wiki/Jon_Snow',
#  '/wiki/Jon_Snow',
#  '/wiki/Sansa_Stark',
#  '/wiki/Sansa_Stark',
#  '/wiki/Arya_Stark',
#  '/wiki/Arya_Stark',
#  '/wiki/Bran_Stark',
#  '/wiki/Bran_Stark',
#  '/wiki/Brienne_of_Tarth',
#  '/wiki/Brienne_of_Tarth',
#  '/wiki/Daenerys_Targaryen',
#  '/wiki/Daenerys_Targaryen',
#  '/wiki/Tyrion_Lannister',
#  '/wiki/Tyrion_Lannister',
#  '/wiki/Missandei',
#  '/wiki/Missandei',
#  '/wiki/Grey_Worm',
#  '/wiki/Grey_Worm',
#  '/wiki/Jorah_Mormont',
#  '/wiki/Jorah_Mormont',
#  '/wiki/Cersei_Lannister',
#  '/wiki/Cersei_Lannister',
#  '/wiki/Jaime_Lannister',
#  '/wiki/Jaime_Lannister',
#  '/wiki/Bronn',
#  '/wiki/Bronn',
#  '/wiki/Gregor_Clegane',
#  '/wiki/Gregor_Clegane',
#  '/wiki/Qyburn',
#  '/wiki/Qyburn',
#  '/wiki/Euron_Greyjoy',
#  '/wiki/Euron_Greyjoy',
#  '/wiki/Yara_Greyjoy',
#  '/wiki/Yara_Greyjoy',
#  '/wiki/Theon_Greyjoy',
#  '/wiki/Theon_Greyjoy',
#  '/wiki/Davos_Seaworth',
#  '/wiki/Davos_Seaworth',
#  '/wiki/Gendry',
#  '/wiki/Gendry',
#  '/wiki/Varys',
#  '/wiki/Varys',
#  '/wiki/Samwell_Tarly',
#  '/wiki/Samwell_Tarly',
#  '/wiki/Tormund',
#  '/wiki/Tormund',
#  '/wiki/Sandor_Clegane',
#  '/wiki/Sandor_Clegane',
#  '/wiki/Melisandre',
#  '/wiki/Melisandre',
#  '/wiki/Special_Report:_Max_Borenstein_prequel_leaks_to_Game_of_Thrones_Wiki',
#  '/wiki/Special_Report:_Max_Borenstein_prequel_leaks_to_Game_of_Thrones_Wiki',
#  '/wiki/Game_of_Thrones_prequel_projects',
#  '/wiki/Game_of_Thrones_prequel_projects',
#  '/wiki/Game_of_Thrones:_The_Long_Night',
#  '/wiki/Game_of_Thrones:_The_Long_Night',
#  '/wiki/Rhaegar_Targaryen',
#  '/wiki/Rhaegar_Targaryen',
#  '/wiki/House_Stark',
#  '/wiki/House_Stark',
#  '/wiki/House_Tully',
#  '/wiki/House_Tully',
#  '/wiki/House_Lannister',
#  '/wiki/House_Lannister',
#  '/wiki/House_Tyrell',
#  '/wiki/House_Tyrell',
#  '/wiki/House_Targaryen',
#  '/wiki/House_Targaryen',
#  '/wiki/House_Bolton',
#  '/wiki/House_Bolton',
#  '/wiki/House_Frey',
#  '/wiki/House_Frey',
#  '/wiki/House_Greyjoy',
#  '/wiki/House_Greyjoy',
#  '/wiki/House_Martell',
#  '/wiki/House_Martell',
#  '/wiki/House_Arryn',
#  '/wiki/House_Arryn',
#  '/wiki/House_Baratheon',
#  '/wiki/House_Baratheon',
#  '/wiki/House_Baratheon_of_King%27s_Landing',
#  '/wiki/House_Baratheon_of_King%27s_Landing',
#  '/wiki/House_Baratheon_of_Dragonstone',
#  '/wiki/House_Baratheon_of_Dragonstone',
#  '/wiki/House_Tarly',
#  '/wiki/House_Tarly',
#  '/wiki/House_Florent',
#  '/wiki/House_Florent',
#  '/wiki/House_Karstark',
#  '/wiki/House_Karstark',
#  '/wiki/House_Umber',
#  '/wiki/House_Umber',
#  '/wiki/House_Manderly',
#  '/wiki/House_Manderly',
#  '/wiki/House_Reed',
#  '/wiki/House_Reed',
#  '/wiki/House_Mormont',
#  '/wiki/House_Mormont',
#  '/wiki/House_Glover',
#  '/wiki/House_Glover',
#  '/wiki/House_Forrester',
#  '/wiki/House_Forrester',
#  '/wiki/House_Whitehill',
#  '/wiki/House_Whitehill',
#  '/wiki/House_Royce',
#  '/wiki/House_Royce',
#  '/wiki/House_Blackfyre',
#  '/wiki/House_Blackfyre',
#  '/wiki/The_Crownlands',
#  '/wiki/The_Crownlands',
#  '/wiki/King%27s_Landing',
#  '/wiki/King%27s_Landing',
#  '/wiki/Dragonstone',
#  '/wiki/Dragonstone',
#  '/wiki/Castle_Stokeworth',
#  '/wiki/Castle_Stokeworth',
#  '/wiki/Westeros',
#  '/wiki/Westeros',
#  '/wiki/The_North',
#  '/wiki/The_North',
#  '/wiki/Winterfell',
#  '/wiki/Winterfell',
#  '/wiki/The_Dreadfort',
#  '/wiki/The_Dreadfort',
#  '/wiki/Moat_Cailin',
#  '/wiki/Moat_Cailin',
#  '/wiki/White_Harbor',
#  '/wiki/White_Harbor',
#  '/wiki/The_North',
#  '/wiki/The_North',
#  '/wiki/Bear_Island',
#  '/wiki/Bear_Island',
#  '/wiki/Deepwood_Motte',
#  '/wiki/Deepwood_Motte',
#  '/wiki/Ironrath',
#  '/wiki/Ironrath',
#  '/wiki/Highpoint',
#  '/wiki/Highpoint',
#  '/wiki/The_Riverlands',
#  '/wiki/The_Riverlands',
#  '/wiki/Riverrun',
#  '/wiki/Riverrun',
#  '/wiki/The_Twins',
#  '/wiki/The_Twins',
#  '/wiki/Harrenhal',
#  '/wiki/Harrenhal',
#  '/wiki/Inn_at_the_Crossroads',
#  '/wiki/Inn_at_the_Crossroads',
#  '/wiki/The_Reach',
#  '/wiki/The_Reach',
#  '/wiki/Highgarden',
#  '/wiki/Highgarden',
#  '/wiki/Oldtown',
#  '/wiki/Oldtown',
#  '/wiki/Horn_Hill',
#  '/wiki/Horn_Hill',
#  '/wiki/The_Arbor',
#  '/wiki/The_Arbor',
#  '/wiki/The_Vale_of_Arryn',
#  '/wiki/The_Vale_of_Arryn',
#  '/wiki/Eyrie',
#  '/wiki/Eyrie',
#  '/wiki/Bloody_Gate',
#  '/wiki/Bloody_Gate',
#  '/wiki/Runestone',
#  '/wiki/Runestone',
#  '/wiki/Gulltown',
#  '/wiki/Gulltown',
#  '/wiki/The_Westerlands',
#  '/wiki/The_Westerlands',
#  '/wiki/Casterly_Rock',
#  '/wiki/Casterly_Rock',
#  '/wiki/Lannisport',
#  '/wiki/Lannisport',
#  '/wiki/Golden_Tooth',
#  '/wiki/Golden_Tooth',
#  '/wiki/Castamere',
#  '/wiki/Castamere',
#  '/wiki/Iron_Islands',
#  '/wiki/Iron_Islands',
#  '/wiki/Pyke_(castle)',
#  '/wiki/Pyke_(castle)',
#  '/wiki/Lordsport',
#  '/wiki/Lordsport',
#  '/wiki/Ironborn',
#  '/wiki/Ironborn',
#  '/wiki/Iron_Fleet',
#  '/wiki/Iron_Fleet',
#  '/wiki/The_Stormlands',
#  '/wiki/The_Stormlands',
#  '/wiki/Storm%27s_End',
#  '/wiki/Storm%27s_End',
#  '/wiki/Tarth',
#  '/wiki/Tarth',
#  '/wiki/Rainwood',
#  '/wiki/Rainwood',
#  '/wiki/Dornish_Marches',
#  '/wiki/Dornish_Marches',
#  '/wiki/Dorne',
#  '/wiki/Dorne',
#  '/wiki/Sunspear',
#  '/wiki/Sunspear',
#  '/wiki/Water_Gardens',
#  '/wiki/Water_Gardens',
#  '/wiki/Tower_of_Joy',
#  '/wiki/Tower_of_Joy',
#  '/wiki/Dornishmen',
#  '/wiki/Dornishmen',
#  '/wiki/The_Wall',
#  '/wiki/The_Wall',
#  '/wiki/Castle_Black',
#  '/wiki/Castle_Black',
#  '/wiki/Eastwatch-by-the-Sea',
#  '/wiki/Eastwatch-by-the-Sea',
#  '/wiki/The_Nightfort',
#  '/wiki/The_Nightfort',
#  '/wiki/The_Gift',
#  '/wiki/The_Gift',
#  '/wiki/Beyond_the_Wall',
#  '/wiki/Beyond_the_Wall',
#  '/wiki/Lands_of_Always_Winter',
#  '/wiki/Lands_of_Always_Winter',
#  '/wiki/Fist_of_the_First_Men',
#  '/wiki/Fist_of_the_First_Men',
#  '/wiki/Hardhome',
#  '/wiki/Hardhome',
#  '/wiki/Free_Folk',
#  '/wiki/Free_Folk',
#  '/wiki/White_Walkers',
#  '/wiki/White_Walkers',
#  '/wiki/Wights',
#  '/wiki/Wights',
#  '/wiki/Giants',
#  '/wiki/Giants',
#  '/wiki/Children_of_the_Forest',
#  '/wiki/Children_of_the_Forest',
#  '/wiki/Three-eyed_Raven',
#  '/wiki/Three-eyed_Raven',
#  '/wiki/The_Known_World',
#  '/wiki/The_Known_World',
#  '/wiki/Essos',
#  '/wiki/Essos',
#  '/wiki/Free_Cities',
#  '/wiki/Free_Cities',
#  '/wiki/Valyrian_Freehold',
#  '/wiki/Valyrian_Freehold',
#  '/wiki/Stepstones',
#  '/wiki/Stepstones',
#  '/wiki/Slaver%27s_Bay',
#  '/wiki/Slaver%27s_Bay',
#  '/wiki/Meereen',
#  '/wiki/Meereen',
#  '/wiki/Yunkai',
#  '/wiki/Yunkai',
#  '/wiki/Astapor',
#  '/wiki/Astapor',
#  '/wiki/Qarth',
#  '/wiki/Qarth',
#  '/wiki/Dothraki',
#  '/wiki/Dothraki',
#  '/wiki/Vaes_Dothrak',
#  '/wiki/Vaes_Dothrak',
#  '/wiki/Lhazar',
#  '/wiki/Lhazar',
#  '/wiki/Yi_Ti',
#  '/wiki/Yi_Ti',
#  '/wiki/Asshai',
#  '/wiki/Asshai',
#  '/wiki/Sothoryos',
#  '/wiki/Sothoryos',
#  '/wiki/Summer_Islands',
#  '/wiki/Summer_Islands',
#  '/wiki/Naath',
#  '/wiki/Naath',
#  '/wiki/Basilisk_Isles',
#  '/wiki/Basilisk_Isles',
#  '/wiki/Ib',
#  '/wiki/Ib',
#  '/wiki/Free_Cities',
#  '/wiki/Free_Cities',
#  '/wiki/Braavos',
#  '/wiki/Braavos',
#  '/wiki/Volantis',
#  '/wiki/Volantis',
#  '/wiki/Pentos',
#  '/wiki/Pentos',
#  '/wiki/Myr',
#  '/wiki/Myr',
#  '/wiki/Lys',
#  '/wiki/Lys',
#  '/wiki/Tyrosh',
#  '/wiki/Tyrosh',
#  '/wiki/Lorath',
#  '/wiki/Lorath',
#  '/wiki/Norvos',
#  '/wiki/Norvos',
#  '/wiki/Qohor',
#  '/wiki/Qohor',
#  '/wiki/Night%27s_Watch',
#  '/wiki/Night%27s_Watch',
#  '/wiki/Maesters',
#  '/wiki/Maesters',
#  '/wiki/Small_Council',
#  '/wiki/Small_Council',
#  '/wiki/City_Watch',
#  '/wiki/City_Watch',
#  '/wiki/Kingsguard',
#  '/wiki/Kingsguard',
#  '/wiki/Iron_Bank_of_Braavos',
#  '/wiki/Iron_Bank_of_Braavos',
#  '/wiki/Faceless_Men',
#  '/wiki/Faceless_Men',
#  '/wiki/Warlocks',
#  '/wiki/Warlocks',
#  '/wiki/Alchemists%27_Guild',
#  '/wiki/Alchemists%27_Guild',
#  '/wiki/Brotherhood_Without_Banners',
#  '/wiki/Brotherhood_Without_Banners',
#  '/wiki/Unsullied',
#  '/wiki/Unsullied',
#  '/wiki/Faith_Militant',
#  '/wiki/Faith_Militant',
#  '/wiki/Sons_of_the_Harpy',
#  '/wiki/Sons_of_the_Harpy',
#  '/wiki/Dosh_khaleen',
#  '/wiki/Dosh_khaleen',
#  '/wiki/Little_birds',
#  '/wiki/Little_birds',
#  '/wiki/Religion',
#  '/wiki/Religion',
#  '/wiki/Old_Gods_of_the_Forest',
#  '/wiki/Old_Gods_of_the_Forest',
#  '/wiki/Faith_of_the_Seven',
#  '/wiki/Faith_of_the_Seven',
#  '/wiki/Drowned_God',
#  '/wiki/Drowned_God',
#  '/wiki/R%27hllor',
#  '/wiki/R%27hllor',
#  '/wiki/Great_Stallion',
#  '/wiki/Great_Stallion',
#  '/wiki/Many-Faced_God',
#  '/wiki/Many-Faced_God',
#  '/wiki/Great_Shepherd',
#  '/wiki/Great_Shepherd',
#  '/wiki/Ghiscari_religion',
#  '/wiki/Ghiscari_religion',
#  '/wiki/Black_Goat_of_Qohor',
#  '/wiki/Black_Goat_of_Qohor',
#  '/wiki/Cultures_and_Peoples',
#  '/wiki/Cultures_and_Peoples',
#  '/wiki/Laws_and_Customs',
#  '/wiki/Laws_and_Customs',
#  '/wiki/Currency',
#  '/wiki/Currency',
#  '/wiki/Food_and_Drink',
#  '/wiki/Food_and_Drink',
#  '/wiki/Costumes',
#  '/wiki/Costumes',
#  '/wiki/Great_House',
#  '/wiki/Great_House',
#  '/wiki/Heraldry',
#  '/wiki/Heraldry',
#  '/wiki/House_words',
#  '/wiki/House_words',
#  '/wiki/Bastardy',
#  '/wiki/Bastardy',
#  '/wiki/Knighthood',
#  '/wiki/Knighthood',
#  '/wiki/Iron_Throne',
#  '/wiki/Iron_Throne',
#  '/wiki/Smallfolk',
#  '/wiki/Smallfolk',
#  '/wiki/Mercenary',
#  '/wiki/Mercenary',
#  '/wiki/Prostitution',
#  '/wiki/Prostitution',
#  '/wiki/Slavery',
#  '/wiki/Slavery',
#  '/wiki/Languages',
#  '/wiki/Languages',
#  '/wiki/Writing_Systems',
#  '/wiki/Writing_Systems',
#  '/wiki/Science_and_Technology#Books',
#  '/wiki/Science_and_Technology#Books',
#  '/wiki/Science_and_Technology#Songs',
#  '/wiki/Science_and_Technology#Songs',
#  '/wiki/Science_and_Technology#Games',
#  '/wiki/Science_and_Technology#Games',
#  '/wiki/Science_and_Technology',
#  '/wiki/Science_and_Technology',
#  '/wiki/Medicine',
#  '/wiki/Medicine',
#  '/wiki/Poison',
#  '/wiki/Poison',
#  '/wiki/Armament',
#  '/wiki/Armament',
#  '/wiki/Ships',
#  '/wiki/Ships',
#  '/wiki/Magic',
#  '/wiki/Magic',
#  '/wiki/Dragonglass',
#  '/wiki/Dragonglass',
#  '/wiki/Warg',
#  '/wiki/Warg',
#  '/wiki/Greensight',
#  '/wiki/Greensight',
#  '/wiki/Prophecies,_visions,_and_dreams',
#  '/wiki/Prophecies,_visions,_and_dreams',
#  '/wiki/Valyrian_steel',
#  '/wiki/Valyrian_steel',
#  '/wiki/Wildfire',
#  '/wiki/Wildfire',
#  '/wiki/Mummers',
#  '/wiki/Mummers',
#  '/wiki/Tournament',
#  '/wiki/Tournament',
#  '/wiki/Kinslaying',
#  '/wiki/Kinslaying',
#  '/wiki/Gender_and_Sexuality',
#  '/wiki/Gender_and_Sexuality',
#  '/wiki/Incest',
#  '/wiki/Incest',
#  '/wiki/Marriage',
#  '/wiki/Marriage',
#  '/wiki/Funeral',
#  '/wiki/Funeral',
#  '/wiki/Guest_right',
#  '/wiki/Guest_right',
#  '/wiki/Animals_and_Plants',
#  '/wiki/Animals_and_Plants',
#  '/wiki/Direwolves',
#  '/wiki/Direwolves',
#  '/wiki/Dragons',
#  '/wiki/Dragons',
#  '/wiki/Ravens',
#  '/wiki/Ravens',
#  '/wiki/Horses',
#  '/wiki/Horses',
#  '/wiki/Mammoths',
#  '/wiki/Mammoths',
#  '/wiki/Cats',
#  '/wiki/Cats',
#  '/wiki/Dogs',
#  '/wiki/Dogs',
#  '/wiki/Weirwood',
#  '/wiki/Weirwood',
#  '/wiki/Milk_of_the_poppy',
#  '/wiki/Milk_of_the_poppy',
#  '/wiki/Timeline',
#  '/wiki/Timeline',
#  '/wiki/Dawn_Age',
#  '/wiki/Dawn_Age',
#  '/wiki/Age_of_Heroes',
#  '/wiki/Age_of_Heroes',
#  '/wiki/Long_Night',
#  '/wiki/Long_Night',
#  '/wiki/Andal_Invasion',
#  '/wiki/Andal_Invasion',
#  '/wiki/Ghiscari_Wars',
#  '/wiki/Ghiscari_Wars',
#  '/wiki/Rhoynish_Wars',
#  '/wiki/Rhoynish_Wars',
#  '/wiki/Nymeria%27s_War',
#  '/wiki/Nymeria%27s_War',
#  '/wiki/Doom_of_Valyria',
#  '/wiki/Doom_of_Valyria',
#  '/wiki/Century_of_Blood',
#  '/wiki/Century_of_Blood',
#  '/wiki/War_of_Conquest',
#  '/wiki/War_of_Conquest',
#  '/wiki/Faith_Militant_uprising',
#  '/wiki/Faith_Militant_uprising',
#  '/wiki/Dance_of_the_Dragons',
#  '/wiki/Dance_of_the_Dragons',
#  '/wiki/Conquest_of_Dorne',
#  '/wiki/Conquest_of_Dorne',
#  '/wiki/Blackfyre_Rebellion',
#  '/wiki/Blackfyre_Rebellion',
#  '/wiki/Trial_by_seven_of_Duncan_the_Tall',
#  '/wiki/Trial_by_seven_of_Duncan_the_Tall',
#  '/wiki/Great_Spring_Sickness',
#  '/wiki/Great_Spring_Sickness',
#  '/wiki/Tragedy_of_Summerhall',
#  '/wiki/Tragedy_of_Summerhall',
#  '/wiki/War_of_the_Ninepenny_Kings',
#  '/wiki/War_of_the_Ninepenny_Kings',
#  '/wiki/Reyne_Rebellion',
#  '/wiki/Reyne_Rebellion',
#  '/wiki/Robert%27s_Rebellion',
#  '/wiki/Robert%27s_Rebellion',
#  '/wiki/Greyjoy_Rebellion',
#  '/wiki/Greyjoy_Rebellion',
#  '/wiki/War_of_the_Five_Kings',
#  '/wiki/War_of_the_Five_Kings',
#  '/wiki/Conflict_Beyond_the_Wall',
#  '/wiki/Conflict_Beyond_the_Wall',
#  '/wiki/Liberation_of_Slaver%27s_Bay',
#  '/wiki/Liberation_of_Slaver%27s_Bay',
#  '/wiki/Battle_of_the_Whispering_Wood',
#  '/wiki/Battle_of_the_Whispering_Wood',
#  '/wiki/Battle_of_the_Blackwater',
#  '/wiki/Battle_of_the_Blackwater',
#  '/wiki/Red_Wedding',
#  '/wiki/Red_Wedding',
#  '/wiki/Purple_Wedding',
#  '/wiki/Purple_Wedding',
#  '/wiki/Battle_of_Castle_Black',
#  '/wiki/Battle_of_Castle_Black',
#  '/wiki/Massacre_at_Hardhome',
#  '/wiki/Massacre_at_Hardhome',
#  '/wiki/Kingsmoot',
#  '/wiki/Kingsmoot',
#  '/wiki/Second_Siege_of_Meereen',
#  '/wiki/Second_Siege_of_Meereen',
#  '/wiki/Battle_of_the_Bastards',
#  '/wiki/Battle_of_the_Bastards',
#  '/wiki/Destruction_of_the_Great_Sept_of_Baelor',
#  '/wiki/Destruction_of_the_Great_Sept_of_Baelor',
#  '/wiki/Game_of_Thrones:_A_Telltale_Games_Series',
#  '/wiki/HBO',
#  '/wiki/Game_of_Thrones',
#  '/wiki/House_Forrester',
#  '/wiki/Telltale%27s_Game_of_Thrones_Super_Walkthrough',
#  'https://gameofthrones.fandom.com/wiki/File:Game_of_Thrones_Season_8_Episode_2_Preview_(HBO)-0',
#  '/wiki/File:Game_of_Thrones_Season_8_Episode_2_Preview_(HBO)-0',
#  'https://gameofthrones.fandom.com/wiki/File:Game_of_Thrones_Season_8_Episode_2_Inside_the_Episode_(HBO)-0',
#  '/wiki/File:Game_of_Thrones_Season_8_Episode_2_Inside_the_Episode_(HBO)-0',
#  '/wiki/Special:Statistics',
#  '/wiki/Special:Statistics',
#  'https://community.fandom.com/wiki/Help:Tutorial',
#  '/wiki/Policies_and_guidelines',
#  '/wiki/Forum:Help_desk',
#  '/wiki/Policies_and_guidelines',
#  '/wiki/Forum:Help_desk',
#  '/wiki/Game_of_Thrones_(TV_series)']

# %% [markdown]
# ### Create a filter for unwanted types of articles

# %%
filter = 'House'

# Retrieve the links about the houses in GOT
links = [t for t in links if re.search(filter, t)]

# remove duplicates
links = list(set(links))
print('Number of links:', len(links))
links
# Out:
# Number of links: 27
# ['/wiki/House_Glover',
#  '/wiki/House_Baratheon',
#  '/wiki/House_Manderly',
#  '/wiki/House_words',
#  '/wiki/House_Mormont',
#  '/wiki/House_Forrester',
#  '/wiki/House_Targaryen',
#  '/wiki/House_Baratheon_of_Dragonstone',
#  '/wiki/House_Blackfyre',
#  '/wiki/House_Frey',
#  '/wiki/House_Florent',
#  '/wiki/Great_House',
#  '/wiki/House_Baratheon_of_King%27s_Landing',
#  '/wiki/House_Arryn',
#  '/wiki/House_Umber',
#  '/wiki/House_Tully',
#  '/wiki/House_Stark',
#  '/wiki/House_Bolton',
#  '/wiki/House_Reed',
#  '/wiki/House_Tarly',
#  '/wiki/House_Lannister',
#  '/wiki/House_Whitehill',
#  '/wiki/House_Royce',
#  '/wiki/House_Tyrell',
#  '/wiki/House_Martell',
#  '/wiki/House_Karstark',
#  '/wiki/House_Greyjoy']
