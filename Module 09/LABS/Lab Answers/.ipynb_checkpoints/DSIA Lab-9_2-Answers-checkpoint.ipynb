# %% [markdown]
# ![image.png](https://i.imgur.com/1WaY7aA.png)
#
# ---
#
#
#
# ---

# %% [markdown]
# #  Data Science and AI
# ## Lab 9.2: Web Scraping
#
# INSTRUCTIONS:
#
# - Run the cells
# - Observe and understand the results
# - Answer the questions

# %% [markdown]
# # Web Scraping in Python (using BeautifulSoup)
#
# ## Scraping Rules
# 1. **Always** check a website’s **Terms and Conditions** before you scrape it. Be careful to read the statements about legal use of data. Usually, the retrieved data should not be used for commercial purposes.
# 2. **Do not** request data from the website too aggressively with a program (also known as spamming), as this may break the website. Make sure the program behaves in a reasonable manner (i.e. acts like a human). One request for one webpage per second is good practice.
# 3. The layout of a website may change from time to time, so make sure to revisit the site and rewrite the code as needed

# %% [markdown]
# ## Find a Page
# Visit the [Fandom](http://fandom.wikia.com) website, find a wikia of your interest and pick a page to work with.

# %% [markdown]
# Open a web page with the browser and inspect it.
#
# Hover the cursor on the text and follow the shaded box surrounding the main text.
#
# From the result, check the main text inside a few levels of HTML tags.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Import Libraries
import regex as re

from urllib.parse import unquote
import urllib3
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Define the content to retrieve (webpage's URL)

# %%
# specify the url
quote_page = 'https://bigbangtheory.fandom.com/wiki/Barry_Kripke'

# %% [markdown]
# ### Retrieve the page
# - Require Internet connection

# %%
# query the website and return the html to the variable ‘page’
http = urllib3.PoolManager()
r = http.request('GET', quote_page)
if r.status == 200:
    page = r.data
    print('Type of the variable \'page\':', page.__class__.__name__)
    print('Page Retrieved. Request Status: %d, Page Size: %d' % (r.status, len(page)))
else:
    print('Some problem occurred. Request Status: %s' % r.status)
# Out:
# Type of the variable 'page': bytes
# Page Retrieved. Request Status: 200, Page Size: 311737

# %% [markdown]
# ### Convert the stream of bytes into a BeautifulSoup representation

# %%
# parse the html using beautiful soup and store in variable `soup`
soup = BeautifulSoup(page, 'html.parser')
print('Type of the variable \'soup\':', soup.__class__.__name__)
# Out:
# Type of the variable 'soup': BeautifulSoup

# %% [markdown]
# ### Check the content
# - The HTML source
# - Includes all tags and scripts
# - Can be long!

# %%
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE doctype html>
# <html class="" dir="ltr" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, user-scalable=yes" name="viewport"/>
#   <meta content="MediaWiki 1.19.24" name="generator">
#    <meta content="The Big Bang Theory Wiki,bigbangtheory,Barry Kripke,Amy Farrah Fowler,Beverly Hofstadter,The Killer Robot Instability,Season 2,Season 3,Season 4,Season 5,Season 6,Season 7,Season 8" name="keywords">
#     <meta content="Barry Kripke, Ph.D. is a Caltech plasma-physicist-turned-string-theorist and he is a colleague of Leonard and Sheldon. He has a case of rhotacism, where he pronounces &amp;quot;r&amp;quot; and &amp;quot;l&amp;quot; as &amp;quot;w&amp;quot;, much like Elmer Fudd in Looney Tunes. With a knack for ribbing people, he is a friend to Leonard, Howard and..." name="description"/>
#     <meta content="summary" name="twitter:card"/>
#     <meta content="@getfandom" name="twitter:site"/>
#     <meta content="

# %% [markdown]
# ### Check the HTML's Title

# %%
print('Title tag :%s:' % soup.title)
print('Title text:%s:' % soup.title.string)
# Out:
# Title tag :<title>Barry Kripke | The Big Bang Theory Wiki | FANDOM powered by Wikia</title>:
# Title text:Barry Kripke | The Big Bang Theory Wiki | FANDOM powered by Wikia:

# %% [markdown]
# ### Find the main content
# - Check if it is possible to use only the relevant data

# %%
tag = 'article'
article = soup.find_all(tag)[0]
print('Type of the variable \'article\':', article.__class__.__name__)
# Out:
# Type of the variable 'article': Tag

# %% [markdown]
# ### Get some of the text
# - Plain text without HTML tags

# %%
# show the first 500 characters after removing redundant newlines
print(re.sub(r'\n\n+', '\n', article.text)[:500])
# Out:
# Barry Kripke
# 			Adult
#
#
# 			Young Adult
#
#
# General Information
# Name
# Barry Kripke
# Born
# Possibly May 12
# Gender
# Male
# Religion
# Unknown
# Nationality
# American
# Occupation
# Physicist
# Portrayed By
# John Ross Bowie
# Relationships
# Relationships
# Amy Farrah Fowler (crush)Beverly Hofstadter (romantic interest)
# Family
# Unknown
# Episode Guide
# First episode in
# "The Killer Robot Instability"
# Last episode in
# The Change Constant
# Seasons Guide
# Seasons
# S1 S2 S3 S4 S5 S6 S7 S8 S9 S10 S11 S12
# Barry Kripke, Ph.D. is

# %% [markdown]
# ### Find the links in the text

# %%
# identify the type of tag to retrieve
tag = 'a'
# create a list with the links from the `<a>` tag
tag_list = [t.get('href') for t in article.find_all(tag)]
print('Size of \'tag_list\':', len(tag_list))
tag_list
# Out:
# Size of 'tag_list': 480
# ['https://vignette.wikia.nocookie.net/bigbangtheory/images/e/e7/Plag16.jpg/revision/latest?cb=20190506103936',
#  'https://vignette.wikia.nocookie.net/bigbangtheory/images/f/f6/BarryKripke.png/revision/latest?cb=20110225223327',
#  '/wiki/John_Ross_Bowie',
#  '/wiki/Amy_Farrah_Fowler',
#  '/wiki/Beverly_Hofstadter',
#  '/wiki/The_Killer_Robot_Instability',
#  '/wiki/The_Change_Constant',
#  '/wiki/Season_2',
#  '/wiki/Season_3',
#  '/wiki/Season_4',
#  '/wiki/Season_5',
#  '/wiki/Season_6',
#  '/wiki/Season_7',
#  '/wiki/Season_8',
#  '/wiki/Season_9',
#  '/wiki/Season_10',
#  '/wiki/Season_11',
#  '/wiki/Season_12',
#  '/wiki/Caltech',
#  'http://en.wikipedia.org/wiki/Plasma_(physics)',
#  '/wiki/String_theory',
#  '/wiki/Leonard',
#  '/wiki/Sheldon',
#  'http://en.wikipedia.org/wiki/rhotacism',
#  'http://en.wikipedia.org/wiki/friend',
#  '/wiki/Leonard',
#  '/wiki/Howard',
#  '/wiki/Rajesh',
#  '#',
#  '/wiki/Season_1',
#  '/wiki/Kripke_Krippler',
#  'http://en.wikipedia.org/wiki/Southern_California',
#  'http://en.wikipedia.org/wiki/Robot',
#  '/wiki/M.O.N.T.E.',
#  '/wiki/Caltech',
#  '/wiki/The_Killer_Robot_Instability',
#  'http://en.wikipedia.org/wiki/anti-proton',
#  'http://en.wikipedia.org/wiki/computer',
#  'http://en.wikipedia.org/wiki/universe',
#  '/wiki/Penny',
#  '/wiki/Howard',
#  '/wiki/Penny',
#  '/wiki/The_Friendship_Algorithm',
#  '/wiki/Season_3',
#  'http://en.wikipedia.org/wiki/monopolar',
#  'http://en.wikipedia.org/wiki/cosmological_constant',
#  '/wiki/The_Electric_Can_Opener_Fluctuation',
#  'http://en.wikipedia.org/wiki/helium',
#  '/wiki/Sheldon%27s_office',
#  'http://en.wikipedia.org/wiki/radio',
#  '/wiki/The_Cafeteria',
#  '/wiki/Leonard',
#  '/wiki/Raj',
#  '/wiki/Sheldon',
#  'http://en.wikipedia.org/wiki/plasma',
#  '/wiki/President_Siebert',
#  'http://en.wikipedia.org/wiki/NSA',
#  '/wiki/The_Vengeance_Formulation',
#  '/wiki/Apartment_4A',
#  '/wiki/Zack_Johnson',
#  '/wiki/Stuart_Bloom',
#  '/wiki/LeVar_Burton',
#  '/wiki/Raj%27s_apartment',
#  'http://en.wikipedia.org/wiki/naked',
#  'http://en.wikipedia.org/wiki/hot_tub',
#  'http://en.wikipedia.org/wiki/karaoke',
#  '/wiki/The_Toast_Derivation',
#  '/wiki/Professor_Rothman',
#  'http://en.wikipedia.org/wiki/particle_physics',
#  'http://en.wikipedia.org/wiki/phone',
#  '/wiki/Siri',
#  '/wiki/The_Beta_Test_Initiation',
#  '/wiki/The_Rothman_Disintegration',
#  '/wiki/Professor_Rothman',
#  '/wiki/President_Siebert',
#  '/wiki/The_Stag_Convergence',
#  'http://en.wikipedia.org/wiki/marriage',
#  'http://en.wikipedia.org/wiki/strippers',
#  'https://vignette.wikia.nocookie.net/bigbangtheory/images/6/60/Kirpike.jpg/revision/latest?cb=20170211054607',
#  '/wiki/File:Kirpike.jpg',
#  '/wiki/The_Cooper/Kripke_Inversion',
#  'http://en.wikipedia.org/wiki/sexual_intercourse',
#  '/wiki/Amy',
#  '/wiki/The_Tenure_Turbulence',
#  'http://en.wikipedia.org/wiki/tenure',
#  '/wiki/The_Discovery_Dissipation',
#  'http://en.wikipedia.org/wiki/superhero',
#  '/wiki/Sheldon',
#  '/wiki/The_Relationship_Diremption',
#  '/wiki/Stephen_Hawking',
#  '/wiki/The_Champagne_Reflection',
#  'http://en.wikipedia.org/wiki/Internet',
#  '/wiki/Sheldon_Cooper_presents_Fun_with_Flags',
#  '/wiki/The_Comic_Book_Store_Regeneration',
#  '/wiki/Amy_Farrah_Fowler',
#  'http://en.wikipedia.org/wiki/cellular_automaton',
#  'http://en.wikipedia.org/wiki/biological_neuron_model',
#  'http://en.wikipedia.org/wiki/light-cone_quantization',
#  '/wiki/The_Perspiration_Implementation',
#  'http://en.wikipedia.org/wiki/fencing',
#  '/wiki/Sheldon_and_Amy',
#  '/wiki/The_Helium_Insufficiency',
#  'http://en.wikipedia.org/wiki/Superfluid_helium-4#Theory',
#  '/wiki/The_Valentino_Submergence',
#  '/wiki/Fun_with_Flags',
#  '/wiki/The_Celebration_Experimentation',
#  '/wiki/Beverly_Hofstadter',
#  '/wiki/The_Geology_Elevation',
#  '/wiki/The_Allowance_Evaporation',
#  '/wiki/Sheldon',
#  '/wiki/Amy',
#  '/wiki/The_Tesla_Recoil',
#  '/wiki/The_Athenaeum_Allocation',
#  '/wiki/Shamy',
#  '/wiki/Caltech',
#  '/wiki/The_Bow_Tie_Asymmetry',
#  '/wiki/The_Grant_Allocation_Derivation',
#  '/wiki/The_Plagiarism%EF%BB%BF%EF%BB%BF%EF%BB%BF_%EF%BB%BFSchism%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF',
#  '/wiki/Dr._Pemberton',
#  '/wiki/The_Change_Constant',
#  'http://en.wikipedia.org/wiki/geek',
#  '/wiki/The_Friendship_Algorithm',
#  'http://en.wikipedia.org/wiki/polo',
#  'http://en.wikipedia.org/wiki/water_polo',
#  'http://en.wikipedia.org/wiki/rock-climbing',
#  '/wiki/The_Rothman_Disintegration',
#  'http://en.wikipedia.org/wiki/gentials',
#  '/wiki/The_Beta_Test_Initiation',
#  'http://en.wikipedia.org/wiki/strip_club',
#  'http://en.wikipedia.org/wiki/apartment',
#  'http://en.wikipedia.org/wiki/buffet',
#  '/wiki/The_Rothman_Disintegration',
#  'http://en.wikipedia.org/wiki/liquor',
#  'http://en.wikipedia.org/wiki/promiscuity',
#  '/wiki/The_Cooper/Kripke_Inversion',
#  'http://en.wikipedia.org/wiki/fusion_reactor',
#  '/wiki/Caltech',
#  '/wiki/Season_1',
#  '/wiki/Season_2',
#  '/wiki/Season_3',
#  '/wiki/Season_4',
#  '/wiki/Season_5',
#  '/wiki/Season_6',
#  '/wiki/Season_7',
#  '/wiki/Season_8',
#  '/wiki/Season_9',
#  '/wiki/Season_10',
#  '/wiki/Season_11',
#  '/wiki/Season_12',
#  '/wiki/Season_1_(Young_Sheldon)',
#  '/wiki/Season_2_(Young_Sheldon)',
#  '/wiki/Season_3_(Young_Sheldon)',
#  '/wiki/Season_1',
#  'http://en.wikipedia.org/wiki/plasma_physicist',
#  'http://en.wikipedia.org/wiki/AdS/CFT_correspondence',
#  'http://en.wikipedia.org/wiki/quark-gluon_plasma',
#  '/wiki/Star_Trek',
#  'http://en.wikipedia.org/wiki/raffle',
#  'http://en.wikipedia.org/wiki/ventriloquism',
#  'http://en.wikipedia.org/wiki/restaurant',
#  'http://en.wikipedia.org/wiki/philosopher',
#  'http://en.wikipedia.org/wiki/logician',
#  'http://en.wikipedia.org/wiki/Saul_Kripke',
#  'http://en.wikipedia.org/wiki/MMORPG',
#  'http://en.wikipedia.org/wiki/Terminator_3',
#  '/wiki/The_Rothman_Disintegration',
#  '/wiki/Professor_Rothman',
#  'http://en.wikipedia.org/wiki/Mexico',
#  '/wiki/German',
#  '/wiki/Season_4',
#  'http://en.wikipedia.org/wiki/Brazill',
#  '/wiki/John_Ross_Bowie',
#  'http://twitter.com/JohnRossBowie/status/376360963768721408',
#  '/wiki/The_Discovery_Dissipation',
#  '/wiki/The_Beta_Test_Initiation',
#  '/wiki/The_Discovery_Dissipation',
#  '/wiki/The_Toast_Derivation',
#  '/wiki/Zack_Johnson',
#  '/wiki/Stuart_Bloom',
#  '/wiki/The_Geology_Elevation',
#  '/wiki/File:Tumblr_mgqku8q9Ub1rjn8bao8_250.jpg',
#  '/wiki/File:Tumblr_mgqjxm2b951qdz44io6_250.jpg',
#  '/wiki/File:BarryKripke.png',
#  '/wiki/File:The_stag_convergence_wheaton,_kripke,_and_the_guys.jpg',
#  '/wiki/File:Sheldon_and_Kripke_disturb_Siebert.png',
#  '/wiki/File:Kripke_is_also_in_the_office.png',
#  '/wiki/File:The_rothman_disintegration_Sheldon_vs_Kripke.jpg',
#  '/wiki/File:The_rothman_disintegration_Sheldon_and_Kripke_in_action.jpg',
#  '/wiki/File:The_rothman_disintegration_Sheldon_and_Kripke_avoid_the_ball.jpg',
#  '/wiki/File:Alg6.jpg',
#  '/wiki/File:Alg4.jpg',
#  '/wiki/File:Alg3.jpg',
#  '/wiki/File:Ship6.jpg',
#  '/wiki/File:Ship5.jpg',
#  '/wiki/File:Ship2.jpg',
#  '/wiki/File:Ler9.jpg',
#  '/wiki/File:Ler4.jpg',
#  '/wiki/File:KripkeLab.png',
#  '/wiki/File:Disc13.jpg',
#  '/wiki/File:Cut5.png',
#  '/wiki/File:Bsa.jpg',
#  '/wiki/File:Den2.png',
#  '/wiki/File:Pim5.jpg',
#  '/wiki/File:Pim3.jpg',
#  '/wiki/File:Crew3.png',
#  '/wiki/File:HS22.png',
#  '/wiki/File:HS21.png',
#  '/wiki/File:HS50.png',
#  '/wiki/File:VV18.png',
#  '/wiki/File:212.jpg',
#  '/wiki/File:BA26.png',
#  '/wiki/File:BA60.png',
#  '/wiki/File:BA52.png',
#  '/wiki/File:BA51.png',
#  '/wiki/File:BA36.png',
#  '/wiki/File:BA33.png',
#  '/wiki/File:Sh2.png',
#  '/wiki/File:SH1.png',
#  '/wiki/File:Date10.jpg',
#  '/wiki/File:Date12.jpg',
#  '/wiki/File:Date18.jpg',
#  '/wiki/File:Date19.jpg',
#  '/wiki/File:Aws197.png',
#  '/wiki/File:Aws198.png',
#  '/wiki/File:Aws201.png',
#  '/wiki/File:Aws200.png',
#  '/wiki/File:Aws202.png',
#  '/wiki/File:LH10.png',
#  '/wiki/File:LH11.png',
#  '/wiki/File:LH24.png',
#  '/wiki/File:TCCO-5.jpg',
#  '/wiki/File:Change13.jpg',
#  '/wiki/Template:Characterf',
#  '//bigbangtheory.fandom.com/wiki/Template:Characterf?action=edit',
#  '/wiki/Template_talk:Characterf',
#  '/wiki/The_Big_Bang_Theory',
#  '/wiki/Category:Characters',
#  '/wiki/Category:Main_Characters',
#  '/wiki/Leonard_Hofstadter',
#  '/wiki/Sheldon_Cooper',
#  '/wiki/Penny_Hofstadter',
#  '/wiki/Howard_Wolowitz',
#  '/wiki/Rajesh_Koothrappali',
#  '/wiki/Amy_Farrah_Fowler',
#  '/wiki/Bernadette_Rostenkowski-Wolowitz',
#  '/wiki/Stuart_Bloom',
#  '/wiki/Emily_Sweeney',
#  '/wiki/Leslie_Winkle',
#  '/wiki/The_Social_Group',
#  '/wiki/Category:Recurring_Characters',
#  '/wiki/Category:Minor_Characters',
#  '/wiki/Debbie_Melvina_Wolowitz',
#  '/wiki/Priya_Koothrappali',
#  '/wiki/V._M._Koothrappali',
#  '/wiki/Mrs._Koothrappali',
#  '/wiki/Stephanie_Barnett',
#  '/wiki/Lucy',
#  '/wiki/Mary_Cooper',
#  '/wiki/Zack_Johnson',
#  '/wiki/Beverly_Hofstadter',
#  '/wiki/Mike_Rostenkowski',
#  '/wiki/Alex_Jensen',
#  '/wiki/Professor_Proton',
#  '/wiki/Missy_Cooper',
#  '/wiki/Ramona_Nowitzki',
#  '/wiki/Dan',
#  '/wiki/Josh_Wolowitz',
#  '/wiki/Dennis_Kim',
#  '/wiki/Althea_Davis',
#  '/wiki/Jeanie',
#  '/wiki/Cinnamon',
#  '/wiki/Mrs._Rostenkowski',
#  '/wiki/Wyatt',
#  '/wiki/Claire',
#  '/wiki/Kurt',
#  '/wiki/Eric_Gablehauser',
#  '/wiki/David_Gibbs',
#  '/wiki/Dimitri',
#  '/wiki/Alfred_Hofstadter',
#  '/wiki/Meemaw',
#  '/wiki/Jimmy_Speckerman',
#  '/wiki/Susan',
#  '/wiki/Randall',
#  '/wiki/Bert_Kibbler',
#  '/wiki/President_Siebert',
#  '/wiki/Janine_Davis',
#  '/wiki/Colonel_Richard_Williams',
#  '/wiki/Halley_Wolowitz',
#  '/wiki/Neil_Michael_Wolowitz',
#  '/wiki/Denise',
#  '/wiki/George_Cooper_Jr.',
#  '/wiki/Larry_Fowler',
#  '/wiki/Anu',
#  '/wiki/George_Cooper_Sr.',
#  '/wiki/Marissa',
#  '/wiki/Category:Cast',
#  '/wiki/Johnny_Galecki',
#  '/wiki/Jim_Parsons',
#  '/wiki/Kaley_Cuoco',
#  '/wiki/Simon_Helberg',
#  '/wiki/Kunal_Nayyar',
#  '/wiki/Mayim_Bialik',
#  '/wiki/Melissa_Rauch',
#  '/wiki/Kevin_Sussman',
#  '/wiki/Laura_Spencer',
#  '/wiki/Sara_Gilbert',
#  '/wiki/Christine_Baranski',
#  '/wiki/Aarti_Mann',
#  '/wiki/John_Ross_Bowie',
#  '/wiki/Casey_Sander',
#  '/wiki/Stephen_Merchant',
#  '/wiki/Sara_Rue',
#  '/wiki/Kara_Luiz',
#  '/wiki/Brian_Thomas_Smith',
#  '/wiki/Margo_Harshman',
#  '/wiki/Alessandra_Torresani',
#  '/wiki/Matt_Bennett',
#  '/wiki/Keith_Carradine',
#  '/wiki/Laurie_Metcalf',
#  '/wiki/Judd_Hirsch',
#  '/wiki/Carol_Ann_Susi',
#  '/wiki/Meagen_Fay',
#  '/wiki/Brian_George',
#  '/wiki/Alice_Amter',
#  '/wiki/Courtney_Henggeler',
#  '/wiki/June_Squibb',
#  '/wiki/Katey_Sagal',
#  '/wiki/Jack_McBrayer',
#  '/wiki/Dean_Norris',
#  '/wiki/Brian_Posehn',
#  '/wiki/Mark_Harelik',
#  '/wiki/Joshua_Malina',
#  '/wiki/Brian_Patrick_Wade',
#  '/wiki/Kate_Micucci',
#  '/wiki/Regina_King',
#  '/wiki/Jerry_O%27Connell',
#  '/wiki/Category:Appeared_As_Themselves',
#  '/wiki/Wil_Wheaton',
#  '/wiki/Mike_Massimino',
#  '/wiki/Stephen_Hawking',
#  '/wiki/Kip_Thorne',
#  '/wiki/Katee_Sackhoff',
#  '/wiki/Steve_Wozniak',
#  '/wiki/Buzz_Aldrin',
#  '/wiki/Summer_Glau',
#  '/wiki/James_Earl_Jones',
#  '/wiki/Carrie_Fisher',
#  '/wiki/Brent_Spiner',
#  '/wiki/Howie_Mandel',
#  '/wiki/Bill_Nye',
#  '/wiki/George_Smoot',
#  '/wiki/George_Takei',
#  '/wiki/LeVar_Burton',
#  '/wiki/Neil_deGrasse_Tyson',
#  '/wiki/Brian_Greene',
#  '/wiki/Charlie_Sheen',
#  '/wiki/Stan_Lee',
#  '/wiki/Adam_West',
#  '/wiki/Mark_Hamill',
#  '/wiki/Kevin_Smith',
#  '/wiki/William_Shatner',
#  '/wiki/Joe_Manganiello',
#  '/wiki/Kareem_Abdul-Jabbar',
#  '/wiki/Sarah_Michelle_Gellar',
#  '/wiki/Category:Crew',
#  '/wiki/Category:Writers',
#  '/wiki/Chuck_Lorre',
#  '/wiki/Bill_Prady',
#  '/wiki/Steven_Molaro',
#  '/wiki/Steve_Holland',
#  '/wiki/Maria_Ferrari',
#  '/wiki/Jim_Reynolds',
#  '/wiki/Eric_Kaplan',
#  '/wiki/Anthony_Del_Broccolo',
#  '/wiki/Lee_Aronsohn',
#  '/wiki/Dave_Goetsch',
#  '/wiki/Tara_Hernandez',
#  '/wiki/Richard_Rosenstock',
#  '/wiki/Category:Directors',
#  '/wiki/Mark_Cendrowski',
#  '/wiki/Peter_Chakos',
#  '/wiki/Anthony_Rich',
#  '/wiki/James_Burrows',
#  '/wiki/Category:Science_Consultant',
#  '/wiki/David_Saltzberg',
#  '/wiki/Steven_V._Silver',
#  '/wiki/Mary_T._Quigley',
#  'http://www.imdb.com/name/nm0497661/',
#  '/wiki/The_History_of_Everything',
#  '/wiki/Barenaked_Ladies',
#  '/wiki/Chuck_Lorre_Productions',
#  '/wiki/Category:Producers',
#  '/wiki/Category:The_Big_Bang_Theory',
#  'http://www.imdb.com/title/tt0898266/fullcredits',
#  'https://bigbangtheory.fandom.com/wiki/Barry_Kripke?oldid=255955',
#  '/wiki/Special:Categories',
#  '/wiki/Category:Characters',
#  '/wiki/Category:Male_Characters',
#  '/wiki/Category:Caltech_Faculty',
#  '/wiki/Category:Scientists',
#  '/wiki/Category:Physicists',
#  '/wiki/Category:Experimental_Physicists',
#  '/wiki/Category:Theoretical_Physicists',
#  '/wiki/Category:Particle_Physicists',
#  '/wiki/Category:Recurring_Characters',
#  '/wiki/Category:Season_2',
#  '/wiki/Category:Season_3',
#  '/wiki/Category:Season_4',
#  '/wiki/Category:Season_5',
#  '/wiki/Category:Season_6',
#  '/wiki/Category:Season_7',
#  '/wiki/Category:Season_8',
#  '/wiki/Category:Season_9',
#  '/wiki/Category:Series_2',
#  '/wiki/Category:Series_3',
#  '/wiki/Category:Series_4',
#  '/wiki/Category:Series_5',
#  '/wiki/Category:Series_6',
#  '/wiki/Category:Series_7',
#  '/wiki/Category:Series_8',
#  '/wiki/Category:Series_9',
#  '/wiki/Category:The_Big_Bang_Theory',
#  '/wiki/Category:Kripke',
#  '/wiki/Category:Single',
#  '/wiki/Category:All_seasons_except_Season_1',
#  '/wiki/Category:Men',
#  '/wiki/Category:Amy%27s_Men',
#  '/wiki/Category:Caltech',
#  '/wiki/Category:Fencing',
#  '/wiki/Category:No_Season_1_appearance',
#  '/wiki/Category:Sheldon%27s_Mortal_Enemies',
#  '/wiki/Category:Ph.D.',
#  '/wiki/Category:No_Season_1_Appearances',
#  '/wiki/Category:Season_2_Characters',
#  '/wiki/Category:Season_3_Characters',
#  '/wiki/Category:Season_4_Characters',
#  '/wiki/Category:Season_5_Characters',
#  '/wiki/Category:Season_6_Characters',
#  '/wiki/Category:Season_7_Characters',
#  '/wiki/Category:Season_8_Characters',
#  '/wiki/Category:Season_9_Characters',
#  '/wiki/Category:No_appearances_in_Season_1',
#  '/wiki/Category:Series_2_characters',
#  '/wiki/Category:Series_3_characters',
#  '/wiki/Category:Series_4_characters',
#  '/wiki/Category:Series_5_characters',
#  '/wiki/Category:Series_6_characters',
#  '/wiki/Category:Series_7_characters',
#  '/wiki/Category:Series_8_characters',
#  '/wiki/Category:Series_9_characters',
#  '/wiki/Category:Beverly%27s_men',
#  '/wiki/Category:Crush_on_Amy',
#  '/wiki/Category:Crush_on_Beverly',
#  '/wiki/Category:Protagonist_%26_Antagonist',
#  '/wiki/Category:Antagonists',
#  '/wiki/Category:Amy%27s_love_interests',
#  '/wiki/Category:Beverly%27s_love_interests',
#  '/wiki/Category:Pasadena',
#  '/wiki/Category:Season_10',
#  '/wiki/Category:Recurring',
#  '/wiki/Category:Season_10_Characters',
#  '/wiki/Category:Series_10_characters',
#  '/wiki/Category:Barry_Kripke',
#  '/wiki/Category:Rivals',
#  '/wiki/Category:Bullies',
#  '/wiki/Category:Season_11_Characters',
#  '/wiki/Category:Penny%27s_antagonists',
#  '/wiki/Category:Barry',
#  '/wiki/Category:Season_11',
#  '/wiki/Category:Sheldon%27s_enemies',
#  '/wiki/Category:Sheldon%27s_enemies_list',
#  '/wiki/Category:First_appearance_in_Season_2',
#  '/wiki/Category:Sheldon%27s_antagonists',
#  '/wiki/Category:Leonard%27s_antagonists',
#  '/wiki/Category:Frenemies',
#  '/wiki/Category:Howard%27s_antagonists',
#  '/wiki/Category:Raj%27s_antagonists',
#  '/wiki/Category:Season_12',
#  '/wiki/Category:Season_12_Characters',
#  'https://www.fandom.com/licensing']

# %%
# keep only the links to the wiki itself
tag_list = [t[6:] for t in tag_list if (t) and (t.startswith('/wiki/'))]
print('Size of \'tag_list\':', len(tag_list))
tag_list
# Out:
# Size of 'tag_list': 416
# ['John_Ross_Bowie',
#  'Amy_Farrah_Fowler',
#  'Beverly_Hofstadter',
#  'The_Killer_Robot_Instability',
#  'The_Change_Constant',
#  'Season_2',
#  'Season_3',
#  'Season_4',
#  'Season_5',
#  'Season_6',
#  'Season_7',
#  'Season_8',
#  'Season_9',
#  'Season_10',
#  'Season_11',
#  'Season_12',
#  'Caltech',
#  'String_theory',
#  'Leonard',
#  'Sheldon',
#  'Leonard',
#  'Howard',
#  'Rajesh',
#  'Season_1',
#  'Kripke_Krippler',
#  'M.O.N.T.E.',
#  'Caltech',
#  'The_Killer_Robot_Instability',
#  'Penny',
#  'Howard',
#  'Penny',
#  'The_Friendship_Algorithm',
#  'Season_3',
#  'The_Electric_Can_Opener_Fluctuation',
#  'Sheldon%27s_office',
#  'The_Cafeteria',
#  'Leonard',
#  'Raj',
#  'Sheldon',
#  'President_Siebert',
#  'The_Vengeance_Formulation',
#  'Apartment_4A',
#  'Zack_Johnson',
#  'Stuart_Bloom',
#  'LeVar_Burton',
#  'Raj%27s_apartment',
#  'The_Toast_Derivation',
#  'Professor_Rothman',
#  'Siri',
#  'The_Beta_Test_Initiation',
#  'The_Rothman_Disintegration',
#  'Professor_Rothman',
#  'President_Siebert',
#  'The_Stag_Convergence',
#  'File:Kirpike.jpg',
#  'The_Cooper/Kripke_Inversion',
#  'Amy',
#  'The_Tenure_Turbulence',
#  'The_Discovery_Dissipation',
#  'Sheldon',
#  'The_Relationship_Diremption',
#  'Stephen_Hawking',
#  'The_Champagne_Reflection',
#  'Sheldon_Cooper_presents_Fun_with_Flags',
#  'The_Comic_Book_Store_Regeneration',
#  'Amy_Farrah_Fowler',
#  'The_Perspiration_Implementation',
#  'Sheldon_and_Amy',
#  'The_Helium_Insufficiency',
#  'The_Valentino_Submergence',
#  'Fun_with_Flags',
#  'The_Celebration_Experimentation',
#  'Beverly_Hofstadter',
#  'The_Geology_Elevation',
#  'The_Allowance_Evaporation',
#  'Sheldon',
#  'Amy',
#  'The_Tesla_Recoil',
#  'The_Athenaeum_Allocation',
#  'Shamy',
#  'Caltech',
#  'The_Bow_Tie_Asymmetry',
#  'The_Grant_Allocation_Derivation',
#  'The_Plagiarism%EF%BB%BF%EF%BB%BF%EF%BB%BF_%EF%BB%BFSchism%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF',
#  'Dr._Pemberton',
#  'The_Change_Constant',
#  'The_Friendship_Algorithm',
#  'The_Rothman_Disintegration',
#  'The_Beta_Test_Initiation',
#  'The_Rothman_Disintegration',
#  'The_Cooper/Kripke_Inversion',
#  'Caltech',
#  'Season_1',
#  'Season_2',
#  'Season_3',
#  'Season_4',
#  'Season_5',
#  'Season_6',
#  'Season_7',
#  'Season_8',
#  'Season_9',
#  'Season_10',
#  'Season_11',
#  'Season_12',
#  'Season_1_(Young_Sheldon)',
#  'Season_2_(Young_Sheldon)',
#  'Season_3_(Young_Sheldon)',
#  'Season_1',
#  'Star_Trek',
#  'The_Rothman_Disintegration',
#  'Professor_Rothman',
#  'German',
#  'Season_4',
#  'John_Ross_Bowie',
#  'The_Discovery_Dissipation',
#  'The_Beta_Test_Initiation',
#  'The_Discovery_Dissipation',
#  'The_Toast_Derivation',
#  'Zack_Johnson',
#  'Stuart_Bloom',
#  'The_Geology_Elevation',
#  'File:Tumblr_mgqku8q9Ub1rjn8bao8_250.jpg',
#  'File:Tumblr_mgqjxm2b951qdz44io6_250.jpg',
#  'File:BarryKripke.png',
#  'File:The_stag_convergence_wheaton,_kripke,_and_the_guys.jpg',
#  'File:Sheldon_and_Kripke_disturb_Siebert.png',
#  'File:Kripke_is_also_in_the_office.png',
#  'File:The_rothman_disintegration_Sheldon_vs_Kripke.jpg',
#  'File:The_rothman_disintegration_Sheldon_and_Kripke_in_action.jpg',
#  'File:The_rothman_disintegration_Sheldon_and_Kripke_avoid_the_ball.jpg',
#  'File:Alg6.jpg',
#  'File:Alg4.jpg',
#  'File:Alg3.jpg',
#  'File:Ship6.jpg',
#  'File:Ship5.jpg',
#  'File:Ship2.jpg',
#  'File:Ler9.jpg',
#  'File:Ler4.jpg',
#  'File:KripkeLab.png',
#  'File:Disc13.jpg',
#  'File:Cut5.png',
#  'File:Bsa.jpg',
#  'File:Den2.png',
#  'File:Pim5.jpg',
#  'File:Pim3.jpg',
#  'File:Crew3.png',
#  'File:HS22.png',
#  'File:HS21.png',
#  'File:HS50.png',
#  'File:VV18.png',
#  'File:212.jpg',
#  'File:BA26.png',
#  'File:BA60.png',
#  'File:BA52.png',
#  'File:BA51.png',
#  'File:BA36.png',
#  'File:BA33.png',
#  'File:Sh2.png',
#  'File:SH1.png',
#  'File:Date10.jpg',
#  'File:Date12.jpg',
#  'File:Date18.jpg',
#  'File:Date19.jpg',
#  'File:Aws197.png',
#  'File:Aws198.png',
#  'File:Aws201.png',
#  'File:Aws200.png',
#  'File:Aws202.png',
#  'File:LH10.png',
#  'File:LH11.png',
#  'File:LH24.png',
#  'File:TCCO-5.jpg',
#  'File:Change13.jpg',
#  'Template:Characterf',
#  'Template_talk:Characterf',
#  'The_Big_Bang_Theory',
#  'Category:Characters',
#  'Category:Main_Characters',
#  'Leonard_Hofstadter',
#  'Sheldon_Cooper',
#  'Penny_Hofstadter',
#  'Howard_Wolowitz',
#  'Rajesh_Koothrappali',
#  'Amy_Farrah_Fowler',
#  'Bernadette_Rostenkowski-Wolowitz',
#  'Stuart_Bloom',
#  'Emily_Sweeney',
#  'Leslie_Winkle',
#  'The_Social_Group',
#  'Category:Recurring_Characters',
#  'Category:Minor_Characters',
#  'Debbie_Melvina_Wolowitz',
#  'Priya_Koothrappali',
#  'V._M._Koothrappali',
#  'Mrs._Koothrappali',
#  'Stephanie_Barnett',
#  'Lucy',
#  'Mary_Cooper',
#  'Zack_Johnson',
#  'Beverly_Hofstadter',
#  'Mike_Rostenkowski',
#  'Alex_Jensen',
#  'Professor_Proton',
#  'Missy_Cooper',
#  'Ramona_Nowitzki',
#  'Dan',
#  'Josh_Wolowitz',
#  'Dennis_Kim',
#  'Althea_Davis',
#  'Jeanie',
#  'Cinnamon',
#  'Mrs._Rostenkowski',
#  'Wyatt',
#  'Claire',
#  'Kurt',
#  'Eric_Gablehauser',
#  'David_Gibbs',
#  'Dimitri',
#  'Alfred_Hofstadter',
#  'Meemaw',
#  'Jimmy_Speckerman',
#  'Susan',
#  'Randall',
#  'Bert_Kibbler',
#  'President_Siebert',
#  'Janine_Davis',
#  'Colonel_Richard_Williams',
#  'Halley_Wolowitz',
#  'Neil_Michael_Wolowitz',
#  'Denise',
#  'George_Cooper_Jr.',
#  'Larry_Fowler',
#  'Anu',
#  'George_Cooper_Sr.',
#  'Marissa',
#  'Category:Cast',
#  'Johnny_Galecki',
#  'Jim_Parsons',
#  'Kaley_Cuoco',
#  'Simon_Helberg',
#  'Kunal_Nayyar',
#  'Mayim_Bialik',
#  'Melissa_Rauch',
#  'Kevin_Sussman',
#  'Laura_Spencer',
#  'Sara_Gilbert',
#  'Christine_Baranski',
#  'Aarti_Mann',
#  'John_Ross_Bowie',
#  'Casey_Sander',
#  'Stephen_Merchant',
#  'Sara_Rue',
#  'Kara_Luiz',
#  'Brian_Thomas_Smith',
#  'Margo_Harshman',
#  'Alessandra_Torresani',
#  'Matt_Bennett',
#  'Keith_Carradine',
#  'Laurie_Metcalf',
#  'Judd_Hirsch',
#  'Carol_Ann_Susi',
#  'Meagen_Fay',
#  'Brian_George',
#  'Alice_Amter',
#  'Courtney_Henggeler',
#  'June_Squibb',
#  'Katey_Sagal',
#  'Jack_McBrayer',
#  'Dean_Norris',
#  'Brian_Posehn',
#  'Mark_Harelik',
#  'Joshua_Malina',
#  'Brian_Patrick_Wade',
#  'Kate_Micucci',
#  'Regina_King',
#  'Jerry_O%27Connell',
#  'Category:Appeared_As_Themselves',
#  'Wil_Wheaton',
#  'Mike_Massimino',
#  'Stephen_Hawking',
#  'Kip_Thorne',
#  'Katee_Sackhoff',
#  'Steve_Wozniak',
#  'Buzz_Aldrin',
#  'Summer_Glau',
#  'James_Earl_Jones',
#  'Carrie_Fisher',
#  'Brent_Spiner',
#  'Howie_Mandel',
#  'Bill_Nye',
#  'George_Smoot',
#  'George_Takei',
#  'LeVar_Burton',
#  'Neil_deGrasse_Tyson',
#  'Brian_Greene',
#  'Charlie_Sheen',
#  'Stan_Lee',
#  'Adam_West',
#  'Mark_Hamill',
#  'Kevin_Smith',
#  'William_Shatner',
#  'Joe_Manganiello',
#  'Kareem_Abdul-Jabbar',
#  'Sarah_Michelle_Gellar',
#  'Category:Crew',
#  'Category:Writers',
#  'Chuck_Lorre',
#  'Bill_Prady',
#  'Steven_Molaro',
#  'Steve_Holland',
#  'Maria_Ferrari',
#  'Jim_Reynolds',
#  'Eric_Kaplan',
#  'Anthony_Del_Broccolo',
#  'Lee_Aronsohn',
#  'Dave_Goetsch',
#  'Tara_Hernandez',
#  'Richard_Rosenstock',
#  'Category:Directors',
#  'Mark_Cendrowski',
#  'Peter_Chakos',
#  'Anthony_Rich',
#  'James_Burrows',
#  'Category:Science_Consultant',
#  'David_Saltzberg',
#  'Steven_V._Silver',
#  'Mary_T._Quigley',
#  'The_History_of_Everything',
#  'Barenaked_Ladies',
#  'Chuck_Lorre_Productions',
#  'Category:Producers',
#  'Category:The_Big_Bang_Theory',
#  'Special:Categories',
#  'Category:Characters',
#  'Category:Male_Characters',
#  'Category:Caltech_Faculty',
#  'Category:Scientists',
#  'Category:Physicists',
#  'Category:Experimental_Physicists',
#  'Category:Theoretical_Physicists',
#  'Category:Particle_Physicists',
#  'Category:Recurring_Characters',
#  'Category:Season_2',
#  'Category:Season_3',
#  'Category:Season_4',
#  'Category:Season_5',
#  'Category:Season_6',
#  'Category:Season_7',
#  'Category:Season_8',
#  'Category:Season_9',
#  'Category:Series_2',
#  'Category:Series_3',
#  'Category:Series_4',
#  'Category:Series_5',
#  'Category:Series_6',
#  'Category:Series_7',
#  'Category:Series_8',
#  'Category:Series_9',
#  'Category:The_Big_Bang_Theory',
#  'Category:Kripke',
#  'Category:Single',
#  'Category:All_seasons_except_Season_1',
#  'Category:Men',
#  'Category:Amy%27s_Men',
#  'Category:Caltech',
#  'Category:Fencing',
#  'Category:No_Season_1_appearance',
#  'Category:Sheldon%27s_Mortal_Enemies',
#  'Category:Ph.D.',
#  'Category:No_Season_1_Appearances',
#  'Category:Season_2_Characters',
#  'Category:Season_3_Characters',
#  'Category:Season_4_Characters',
#  'Category:Season_5_Characters',
#  'Category:Season_6_Characters',
#  'Category:Season_7_Characters',
#  'Category:Season_8_Characters',
#  'Category:Season_9_Characters',
#  'Category:No_appearances_in_Season_1',
#  'Category:Series_2_characters',
#  'Category:Series_3_characters',
#  'Category:Series_4_characters',
#  'Category:Series_5_characters',
#  'Category:Series_6_characters',
#  'Category:Series_7_characters',
#  'Category:Series_8_characters',
#  'Category:Series_9_characters',
#  'Category:Beverly%27s_men',
#  'Category:Crush_on_Amy',
#  'Category:Crush_on_Beverly',
#  'Category:Protagonist_%26_Antagonist',
#  'Category:Antagonists',
#  'Category:Amy%27s_love_interests',
#  'Category:Beverly%27s_love_interests',
#  'Category:Pasadena',
#  'Category:Season_10',
#  'Category:Recurring',
#  'Category:Season_10_Characters',
#  'Category:Series_10_characters',
#  'Category:Barry_Kripke',
#  'Category:Rivals',
#  'Category:Bullies',
#  'Category:Season_11_Characters',
#  'Category:Penny%27s_antagonists',
#  'Category:Barry',
#  'Category:Season_11',
#  'Category:Sheldon%27s_enemies',
#  'Category:Sheldon%27s_enemies_list',
#  'Category:First_appearance_in_Season_2',
#  'Category:Sheldon%27s_antagonists',
#  'Category:Leonard%27s_antagonists',
#  'Category:Frenemies',
#  'Category:Howard%27s_antagonists',
#  'Category:Raj%27s_antagonists',
#  'Category:Season_12',
#  'Category:Season_12_Characters']

# %%
# create a filter for undesired links
filter  = '(%s)' % '|'.join([
    'Season_',
    'Category:',
    'File:',
    'Help:',
    'Portal:',
    'action=',
    'Special:',
    'Talk:'
])
# remove the links that are found in the filter
tag_list = [t for t in tag_list if not re.search(filter, t)]
print('Size of \'tag_list\':', len(tag_list))
tag_list
# Out:
# Size of 'tag_list': 237
# ['John_Ross_Bowie',
#  'Amy_Farrah_Fowler',
#  'Beverly_Hofstadter',
#  'The_Killer_Robot_Instability',
#  'The_Change_Constant',
#  'Caltech',
#  'String_theory',
#  'Leonard',
#  'Sheldon',
#  'Leonard',
#  'Howard',
#  'Rajesh',
#  'Kripke_Krippler',
#  'M.O.N.T.E.',
#  'Caltech',
#  'The_Killer_Robot_Instability',
#  'Penny',
#  'Howard',
#  'Penny',
#  'The_Friendship_Algorithm',
#  'The_Electric_Can_Opener_Fluctuation',
#  'Sheldon%27s_office',
#  'The_Cafeteria',
#  'Leonard',
#  'Raj',
#  'Sheldon',
#  'President_Siebert',
#  'The_Vengeance_Formulation',
#  'Apartment_4A',
#  'Zack_Johnson',
#  'Stuart_Bloom',
#  'LeVar_Burton',
#  'Raj%27s_apartment',
#  'The_Toast_Derivation',
#  'Professor_Rothman',
#  'Siri',
#  'The_Beta_Test_Initiation',
#  'The_Rothman_Disintegration',
#  'Professor_Rothman',
#  'President_Siebert',
#  'The_Stag_Convergence',
#  'The_Cooper/Kripke_Inversion',
#  'Amy',
#  'The_Tenure_Turbulence',
#  'The_Discovery_Dissipation',
#  'Sheldon',
#  'The_Relationship_Diremption',
#  'Stephen_Hawking',
#  'The_Champagne_Reflection',
#  'Sheldon_Cooper_presents_Fun_with_Flags',
#  'The_Comic_Book_Store_Regeneration',
#  'Amy_Farrah_Fowler',
#  'The_Perspiration_Implementation',
#  'Sheldon_and_Amy',
#  'The_Helium_Insufficiency',
#  'The_Valentino_Submergence',
#  'Fun_with_Flags',
#  'The_Celebration_Experimentation',
#  'Beverly_Hofstadter',
#  'The_Geology_Elevation',
#  'The_Allowance_Evaporation',
#  'Sheldon',
#  'Amy',
#  'The_Tesla_Recoil',
#  'The_Athenaeum_Allocation',
#  'Shamy',
#  'Caltech',
#  'The_Bow_Tie_Asymmetry',
#  'The_Grant_Allocation_Derivation',
#  'The_Plagiarism%EF%BB%BF%EF%BB%BF%EF%BB%BF_%EF%BB%BFSchism%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF',
#  'Dr._Pemberton',
#  'The_Change_Constant',
#  'The_Friendship_Algorithm',
#  'The_Rothman_Disintegration',
#  'The_Beta_Test_Initiation',
#  'The_Rothman_Disintegration',
#  'The_Cooper/Kripke_Inversion',
#  'Caltech',
#  'Star_Trek',
#  'The_Rothman_Disintegration',
#  'Professor_Rothman',
#  'German',
#  'John_Ross_Bowie',
#  'The_Discovery_Dissipation',
#  'The_Beta_Test_Initiation',
#  'The_Discovery_Dissipation',
#  'The_Toast_Derivation',
#  'Zack_Johnson',
#  'Stuart_Bloom',
#  'The_Geology_Elevation',
#  'Template:Characterf',
#  'Template_talk:Characterf',
#  'The_Big_Bang_Theory',
#  'Leonard_Hofstadter',
#  'Sheldon_Cooper',
#  'Penny_Hofstadter',
#  'Howard_Wolowitz',
#  'Rajesh_Koothrappali',
#  'Amy_Farrah_Fowler',
#  'Bernadette_Rostenkowski-Wolowitz',
#  'Stuart_Bloom',
#  'Emily_Sweeney',
#  'Leslie_Winkle',
#  'The_Social_Group',
#  'Debbie_Melvina_Wolowitz',
#  'Priya_Koothrappali',
#  'V._M._Koothrappali',
#  'Mrs._Koothrappali',
#  'Stephanie_Barnett',
#  'Lucy',
#  'Mary_Cooper',
#  'Zack_Johnson',
#  'Beverly_Hofstadter',
#  'Mike_Rostenkowski',
#  'Alex_Jensen',
#  'Professor_Proton',
#  'Missy_Cooper',
#  'Ramona_Nowitzki',
#  'Dan',
#  'Josh_Wolowitz',
#  'Dennis_Kim',
#  'Althea_Davis',
#  'Jeanie',
#  'Cinnamon',
#  'Mrs._Rostenkowski',
#  'Wyatt',
#  'Claire',
#  'Kurt',
#  'Eric_Gablehauser',
#  'David_Gibbs',
#  'Dimitri',
#  'Alfred_Hofstadter',
#  'Meemaw',
#  'Jimmy_Speckerman',
#  'Susan',
#  'Randall',
#  'Bert_Kibbler',
#  'President_Siebert',
#  'Janine_Davis',
#  'Colonel_Richard_Williams',
#  'Halley_Wolowitz',
#  'Neil_Michael_Wolowitz',
#  'Denise',
#  'George_Cooper_Jr.',
#  'Larry_Fowler',
#  'Anu',
#  'George_Cooper_Sr.',
#  'Marissa',
#  'Johnny_Galecki',
#  'Jim_Parsons',
#  'Kaley_Cuoco',
#  'Simon_Helberg',
#  'Kunal_Nayyar',
#  'Mayim_Bialik',
#  'Melissa_Rauch',
#  'Kevin_Sussman',
#  'Laura_Spencer',
#  'Sara_Gilbert',
#  'Christine_Baranski',
#  'Aarti_Mann',
#  'John_Ross_Bowie',
#  'Casey_Sander',
#  'Stephen_Merchant',
#  'Sara_Rue',
#  'Kara_Luiz',
#  'Brian_Thomas_Smith',
#  'Margo_Harshman',
#  'Alessandra_Torresani',
#  'Matt_Bennett',
#  'Keith_Carradine',
#  'Laurie_Metcalf',
#  'Judd_Hirsch',
#  'Carol_Ann_Susi',
#  'Meagen_Fay',
#  'Brian_George',
#  'Alice_Amter',
#  'Courtney_Henggeler',
#  'June_Squibb',
#  'Katey_Sagal',
#  'Jack_McBrayer',
#  'Dean_Norris',
#  'Brian_Posehn',
#  'Mark_Harelik',
#  'Joshua_Malina',
#  'Brian_Patrick_Wade',
#  'Kate_Micucci',
#  'Regina_King',
#  'Jerry_O%27Connell',
#  'Wil_Wheaton',
#  'Mike_Massimino',
#  'Stephen_Hawking',
#  'Kip_Thorne',
#  'Katee_Sackhoff',
#  'Steve_Wozniak',
#  'Buzz_Aldrin',
#  'Summer_Glau',
#  'James_Earl_Jones',
#  'Carrie_Fisher',
#  'Brent_Spiner',
#  'Howie_Mandel',
#  'Bill_Nye',
#  'George_Smoot',
#  'George_Takei',
#  'LeVar_Burton',
#  'Neil_deGrasse_Tyson',
#  'Brian_Greene',
#  'Charlie_Sheen',
#  'Stan_Lee',
#  'Adam_West',
#  'Mark_Hamill',
#  'Kevin_Smith',
#  'William_Shatner',
#  'Joe_Manganiello',
#  'Kareem_Abdul-Jabbar',
#  'Sarah_Michelle_Gellar',
#  'Chuck_Lorre',
#  'Bill_Prady',
#  'Steven_Molaro',
#  'Steve_Holland',
#  'Maria_Ferrari',
#  'Jim_Reynolds',
#  'Eric_Kaplan',
#  'Anthony_Del_Broccolo',
#  'Lee_Aronsohn',
#  'Dave_Goetsch',
#  'Tara_Hernandez',
#  'Richard_Rosenstock',
#  'Mark_Cendrowski',
#  'Peter_Chakos',
#  'Anthony_Rich',
#  'James_Burrows',
#  'David_Saltzberg',
#  'Steven_V._Silver',
#  'Mary_T._Quigley',
#  'The_History_of_Everything',
#  'Barenaked_Ladies',
#  'Chuck_Lorre_Productions']

# %%
# remove duplicates
tag_list = list(set(tag_list))
print('Size of \'tag_list\':', len(tag_list))
tag_list
# Out:
# Size of 'tag_list': 197
# ['Mark_Cendrowski',
#  'Denise',
#  'Eric_Gablehauser',
#  'Summer_Glau',
#  'The_Vengeance_Formulation',
#  'Maria_Ferrari',
#  'Dimitri',
#  'Professor_Rothman',
#  'Alice_Amter',
#  'Kaley_Cuoco',
#  'Joshua_Malina',
#  'Neil_Michael_Wolowitz',
#  'The_Athenaeum_Allocation',
#  'Star_Trek',
#  'The_Celebration_Experimentation',
#  'Katey_Sagal',
#  'June_Squibb',
#  'The_Bow_Tie_Asymmetry',
#  'Jack_McBrayer',
#  'Meemaw',
#  'The_Change_Constant',
#  'Jim_Parsons',
#  'Bert_Kibbler',
#  'M.O.N.T.E.',
#  'The_Relationship_Diremption',
#  'Tara_Hernandez',
#  'Sara_Rue',
#  'The_Killer_Robot_Instability',
#  'Alex_Jensen',
#  'Joe_Manganiello',
#  'Kevin_Sussman',
#  'The_Electric_Can_Opener_Fluctuation',
#  'Jerry_O%27Connell',
#  'Sheldon%27s_office',
#  'Emily_Sweeney',
#  'Amy_Farrah_Fowler',
#  'Sheldon_Cooper',
#  'Bernadette_Rostenkowski-Wolowitz',
#  'Buzz_Aldrin',
#  'The_Champagne_Reflection',
#  'Dennis_Kim',
#  'Colonel_Richard_Williams',
#  'Christine_Baranski',
#  'Eric_Kaplan',
#  'Peter_Chakos',
#  'The_Geology_Elevation',
#  'David_Gibbs',
#  'Sheldon',
#  'James_Earl_Jones',
#  'Steven_Molaro',
#  'The_Valentino_Submergence',
#  'George_Cooper_Jr.',
#  'Melissa_Rauch',
#  'The_Beta_Test_Initiation',
#  'Anthony_Del_Broccolo',
#  'Judd_Hirsch',
#  'Template:Characterf',
#  'The_Cooper/Kripke_Inversion',
#  'Priya_Koothrappali',
#  'Mrs._Koothrappali',
#  'Larry_Fowler',
#  'Lucy',
#  'Laurie_Metcalf',
#  'Shamy',
#  'Aarti_Mann',
#  'Zack_Johnson',
#  'Regina_King',
#  'Neil_deGrasse_Tyson',
#  'Amy',
#  'Jimmy_Speckerman',
#  'Kara_Luiz',
#  'Lee_Aronsohn',
#  'Margo_Harshman',
#  'Adam_West',
#  'Carrie_Fisher',
#  'The_Tenure_Turbulence',
#  'Leonard_Hofstadter',
#  'Brian_Patrick_Wade',
#  'Sarah_Michelle_Gellar',
#  'James_Burrows',
#  'Mrs._Rostenkowski',
#  'Raj%27s_apartment',
#  'Mayim_Bialik',
#  'Stephanie_Barnett',
#  'Meagen_Fay',
#  'The_History_of_Everything',
#  'Sara_Gilbert',
#  'Fun_with_Flags',
#  'Howie_Mandel',
#  'Randall',
#  'Penny',
#  'Sheldon_and_Amy',
#  'The_Grant_Allocation_Derivation',
#  'President_Siebert',
#  'Steve_Wozniak',
#  'The_Social_Group',
#  'Chuck_Lorre',
#  'Wyatt',
#  'Template_talk:Characterf',
#  'Stan_Lee',
#  'Leonard',
#  'Bill_Prady',
#  'Sheldon_Cooper_presents_Fun_with_Flags',
#  'Alessandra_Torresani',
#  'String_theory',
#  'Marissa',
#  'Mark_Harelik',
#  'George_Takei',
#  'Dr._Pemberton',
#  'Dan',
#  'Keith_Carradine',
#  'Chuck_Lorre_Productions',
#  'V._M._Koothrappali',
#  'Apartment_4A',
#  'Kurt',
#  'Jeanie',
#  'Ramona_Nowitzki',
#  'The_Cafeteria',
#  'Leslie_Winkle',
#  'The_Allowance_Evaporation',
#  'Kareem_Abdul-Jabbar',
#  'Brent_Spiner',
#  'Laura_Spencer',
#  'The_Rothman_Disintegration',
#  'The_Discovery_Dissipation',
#  'The_Tesla_Recoil',
#  'Dean_Norris',
#  'Richard_Rosenstock',
#  'Caltech',
#  'Debbie_Melvina_Wolowitz',
#  'Beverly_Hofstadter',
#  'Susan',
#  'George_Cooper_Sr.',
#  'Jim_Reynolds',
#  'Missy_Cooper',
#  'Mary_Cooper',
#  'Cinnamon',
#  'Barenaked_Ladies',
#  'The_Big_Bang_Theory',
#  'Kip_Thorne',
#  'Courtney_Henggeler',
#  'Brian_Greene',
#  'The_Stag_Convergence',
#  'The_Friendship_Algorithm',
#  'John_Ross_Bowie',
#  'Raj',
#  'Carol_Ann_Susi',
#  'Claire',
#  'Rajesh',
#  'David_Saltzberg',
#  'Katee_Sackhoff',
#  'Brian_George',
#  'Mary_T._Quigley',
#  'Kunal_Nayyar',
#  'Kripke_Krippler',
#  'Stuart_Bloom',
#  'Anu',
#  'George_Smoot',
#  'Mike_Massimino',
#  'Anthony_Rich',
#  'Alfred_Hofstadter',
#  'Mike_Rostenkowski',
#  'The_Helium_Insufficiency',
#  'Brian_Posehn',
#  'Wil_Wheaton',
#  'Brian_Thomas_Smith',
#  'Janine_Davis',
#  'Stephen_Merchant',
#  'Charlie_Sheen',
#  'Stephen_Hawking',
#  'Kate_Micucci',
#  'Mark_Hamill',
#  'Simon_Helberg',
#  'Althea_Davis',
#  'The_Perspiration_Implementation',
#  'Kevin_Smith',
#  'Steven_V._Silver',
#  'William_Shatner',
#  'German',
#  'Bill_Nye',
#  'Matt_Bennett',
#  'LeVar_Burton',
#  'Penny_Hofstadter',
#  'Casey_Sander',
#  'Dave_Goetsch',
#  'Professor_Proton',
#  'The_Comic_Book_Store_Regeneration',
#  'Halley_Wolowitz',
#  'Johnny_Galecki',
#  'The_Plagiarism%EF%BB%BF%EF%BB%BF%EF%BB%BF_%EF%BB%BFSchism%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF%EF%BB%BF',
#  'Josh_Wolowitz',
#  'The_Toast_Derivation',
#  'Howard',
#  'Howard_Wolowitz',
#  'Steve_Holland',
#  'Siri',
#  'Rajesh_Koothrappali']

# %%
# convert escaped sequences
tag_list = [unquote(t) for t in tag_list]
print('Size of \'tag_list\':', len(tag_list))
tag_list
# Out:
# Size of 'tag_list': 197
# ['Mark_Cendrowski',
#  'Denise',
#  'Eric_Gablehauser',
#  'Summer_Glau',
#  'The_Vengeance_Formulation',
#  'Maria_Ferrari',
#  'Dimitri',
#  'Professor_Rothman',
#  'Alice_Amter',
#  'Kaley_Cuoco',
#  'Joshua_Malina',
#  'Neil_Michael_Wolowitz',
#  'The_Athenaeum_Allocation',
#  'Star_Trek',
#  'The_Celebration_Experimentation',
#  'Katey_Sagal',
#  'June_Squibb',
#  'The_Bow_Tie_Asymmetry',
#  'Jack_McBrayer',
#  'Meemaw',
#  'The_Change_Constant',
#  'Jim_Parsons',
#  'Bert_Kibbler',
#  'M.O.N.T.E.',
#  'The_Relationship_Diremption',
#  'Tara_Hernandez',
#  'Sara_Rue',
#  'The_Killer_Robot_Instability',
#  'Alex_Jensen',
#  'Joe_Manganiello',
#  'Kevin_Sussman',
#  'The_Electric_Can_Opener_Fluctuation',
#  "Jerry_O'Connell",
#  "Sheldon's_office",
#  'Emily_Sweeney',
#  'Amy_Farrah_Fowler',
#  'Sheldon_Cooper',
#  'Bernadette_Rostenkowski-Wolowitz',
#  'Buzz_Aldrin',
#  'The_Champagne_Reflection',
#  'Dennis_Kim',
#  'Colonel_Richard_Williams',
#  'Christine_Baranski',
#  'Eric_Kaplan',
#  'Peter_Chakos',
#  'The_Geology_Elevation',
#  'David_Gibbs',
#  'Sheldon',
#  'James_Earl_Jones',
#  'Steven_Molaro',
#  'The_Valentino_Submergence',
#  'George_Cooper_Jr.',
#  'Melissa_Rauch',
#  'The_Beta_Test_Initiation',
#  'Anthony_Del_Broccolo',
#  'Judd_Hirsch',
#  'Template:Characterf',
#  'The_Cooper/Kripke_Inversion',
#  'Priya_Koothrappali',
#  'Mrs._Koothrappali',
#  'Larry_Fowler',
#  'Lucy',
#  'Laurie_Metcalf',
#  'Shamy',
#  'Aarti_Mann',
#  'Zack_Johnson',
#  'Regina_King',
#  'Neil_deGrasse_Tyson',
#  'Amy',
#  'Jimmy_Speckerman',
#  'Kara_Luiz',
#  'Lee_Aronsohn',
#  'Margo_Harshman',
#  'Adam_West',
#  'Carrie_Fisher',
#  'The_Tenure_Turbulence',
#  'Leonard_Hofstadter',
#  'Brian_Patrick_Wade',
#  'Sarah_Michelle_Gellar',
#  'James_Burrows',
#  'Mrs._Rostenkowski',
#  "Raj's_apartment",
#  'Mayim_Bialik',
#  'Stephanie_Barnett',
#  'Meagen_Fay',
#  'The_History_of_Everything',
#  'Sara_Gilbert',
#  'Fun_with_Flags',
#  'Howie_Mandel',
#  'Randall',
#  'Penny',
#  'Sheldon_and_Amy',
#  'The_Grant_Allocation_Derivation',
#  'President_Siebert',
#  'Steve_Wozniak',
#  'The_Social_Group',
#  'Chuck_Lorre',
#  'Wyatt',
#  'Template_talk:Characterf',
#  'Stan_Lee',
#  'Leonard',
#  'Bill_Prady',
#  'Sheldon_Cooper_presents_Fun_with_Flags',
#  'Alessandra_Torresani',
#  'String_theory',
#  'Marissa',
#  'Mark_Harelik',
#  'George_Takei',
#  'Dr._Pemberton',
#  'Dan',
#  'Keith_Carradine',
#  'Chuck_Lorre_Productions',
#  'V._M._Koothrappali',
#  'Apartment_4A',
#  'Kurt',
#  'Jeanie',
#  'Ramona_Nowitzki',
#  'The_Cafeteria',
#  'Leslie_Winkle',
#  'The_Allowance_Evaporation',
#  'Kareem_Abdul-Jabbar',
#  'Brent_Spiner',
#  'Laura_Spencer',
#  'The_Rothman_Disintegration',
#  'The_Discovery_Dissipation',
#  'The_Tesla_Recoil',
#  'Dean_Norris',
#  'Richard_Rosenstock',
#  'Caltech',
#  'Debbie_Melvina_Wolowitz',
#  'Beverly_Hofstadter',
#  'Susan',
#  'George_Cooper_Sr.',
#  'Jim_Reynolds',
#  'Missy_Cooper',
#  'Mary_Cooper',
#  'Cinnamon',
#  'Barenaked_Ladies',
#  'The_Big_Bang_Theory',
#  'Kip_Thorne',
#  'Courtney_Henggeler',
#  'Brian_Greene',
#  'The_Stag_Convergence',
#  'The_Friendship_Algorithm',
#  'John_Ross_Bowie',
#  'Raj',
#  'Carol_Ann_Susi',
#  'Claire',
#  'Rajesh',
#  'David_Saltzberg',
#  'Katee_Sackhoff',
#  'Brian_George',
#  'Mary_T._Quigley',
#  'Kunal_Nayyar',
#  'Kripke_Krippler',
#  'Stuart_Bloom',
#  'Anu',
#  'George_Smoot',
#  'Mike_Massimino',
#  'Anthony_Rich',
#  'Alfred_Hofstadter',
#  'Mike_Rostenkowski',
#  'The_Helium_Insufficiency',
#  'Brian_Posehn',
#  'Wil_Wheaton',
#  'Brian_Thomas_Smith',
#  'Janine_Davis',
#  'Stephen_Merchant',
#  'Charlie_Sheen',
#  'Stephen_Hawking',
#  'Kate_Micucci',
#  'Mark_Hamill',
#  'Simon_Helberg',
#  'Althea_Davis',
#  'The_Perspiration_Implementation',
#  'Kevin_Smith',
#  'Steven_V._Silver',
#  'William_Shatner',
#  'German',
#  'Bill_Nye',
#  'Matt_Bennett',
#  'LeVar_Burton',
#  'Penny_Hofstadter',
#  'Casey_Sander',
#  'Dave_Goetsch',
#  'Professor_Proton',
#  'The_Comic_Book_Store_Regeneration',
#  'Halley_Wolowitz',
#  'Johnny_Galecki',
#  'The_Plagiarism\ufeff\ufeff\ufeff_\ufeffSchism\ufeff\ufeff\ufeff\ufeff\ufeff\ufeff',
#  'Josh_Wolowitz',
#  'The_Toast_Derivation',
#  'Howard',
#  'Howard_Wolowitz',
#  'Steve_Holland',
#  'Siri',
#  'Rajesh_Koothrappali']

# %%
# convert underscore to space
tag_list = [re.sub('_', ' ', t) for t in tag_list]
print('Size of \'tag_list\':', len(tag_list))
tag_list
# Out:
# Size of 'tag_list': 197
# ['Mark Cendrowski',
#  'Denise',
#  'Eric Gablehauser',
#  'Summer Glau',
#  'The Vengeance Formulation',
#  'Maria Ferrari',
#  'Dimitri',
#  'Professor Rothman',
#  'Alice Amter',
#  'Kaley Cuoco',
#  'Joshua Malina',
#  'Neil Michael Wolowitz',
#  'The Athenaeum Allocation',
#  'Star Trek',
#  'The Celebration Experimentation',
#  'Katey Sagal',
#  'June Squibb',
#  'The Bow Tie Asymmetry',
#  'Jack McBrayer',
#  'Meemaw',
#  'The Change Constant',
#  'Jim Parsons',
#  'Bert Kibbler',
#  'M.O.N.T.E.',
#  'The Relationship Diremption',
#  'Tara Hernandez',
#  'Sara Rue',
#  'The Killer Robot Instability',
#  'Alex Jensen',
#  'Joe Manganiello',
#  'Kevin Sussman',
#  'The Electric Can Opener Fluctuation',
#  "Jerry O'Connell",
#  "Sheldon's office",
#  'Emily Sweeney',
#  'Amy Farrah Fowler',
#  'Sheldon Cooper',
#  'Bernadette Rostenkowski-Wolowitz',
#  'Buzz Aldrin',
#  'The Champagne Reflection',
#  'Dennis Kim',
#  'Colonel Richard Williams',
#  'Christine Baranski',
#  'Eric Kaplan',
#  'Peter Chakos',
#  'The Geology Elevation',
#  'David Gibbs',
#  'Sheldon',
#  'James Earl Jones',
#  'Steven Molaro',
#  'The Valentino Submergence',
#  'George Cooper Jr.',
#  'Melissa Rauch',
#  'The Beta Test Initiation',
#  'Anthony Del Broccolo',
#  'Judd Hirsch',
#  'Template:Characterf',
#  'The Cooper/Kripke Inversion',
#  'Priya Koothrappali',
#  'Mrs. Koothrappali',
#  'Larry Fowler',
#  'Lucy',
#  'Laurie Metcalf',
#  'Shamy',
#  'Aarti Mann',
#  'Zack Johnson',
#  'Regina King',
#  'Neil deGrasse Tyson',
#  'Amy',
#  'Jimmy Speckerman',
#  'Kara Luiz',
#  'Lee Aronsohn',
#  'Margo Harshman',
#  'Adam West',
#  'Carrie Fisher',
#  'The Tenure Turbulence',
#  'Leonard Hofstadter',
#  'Brian Patrick Wade',
#  'Sarah Michelle Gellar',
#  'James Burrows',
#  'Mrs. Rostenkowski',
#  "Raj's apartment",
#  'Mayim Bialik',
#  'Stephanie Barnett',
#  'Meagen Fay',
#  'The History of Everything',
#  'Sara Gilbert',
#  'Fun with Flags',
#  'Howie Mandel',
#  'Randall',
#  'Penny',
#  'Sheldon and Amy',
#  'The Grant Allocation Derivation',
#  'President Siebert',
#  'Steve Wozniak',
#  'The Social Group',
#  'Chuck Lorre',
#  'Wyatt',
#  'Template talk:Characterf',
#  'Stan Lee',
#  'Leonard',
#  'Bill Prady',
#  'Sheldon Cooper presents Fun with Flags',
#  'Alessandra Torresani',
#  'String theory',
#  'Marissa',
#  'Mark Harelik',
#  'George Takei',
#  'Dr. Pemberton',
#  'Dan',
#  'Keith Carradine',
#  'Chuck Lorre Productions',
#  'V. M. Koothrappali',
#  'Apartment 4A',
#  'Kurt',
#  'Jeanie',
#  'Ramona Nowitzki',
#  'The Cafeteria',
#  'Leslie Winkle',
#  'The Allowance Evaporation',
#  'Kareem Abdul-Jabbar',
#  'Brent Spiner',
#  'Laura Spencer',
#  'The Rothman Disintegration',
#  'The Discovery Dissipation',
#  'The Tesla Recoil',
#  'Dean Norris',
#  'Richard Rosenstock',
#  'Caltech',
#  'Debbie Melvina Wolowitz',
#  'Beverly Hofstadter',
#  'Susan',
#  'George Cooper Sr.',
#  'Jim Reynolds',
#  'Missy Cooper',
#  'Mary Cooper',
#  'Cinnamon',
#  'Barenaked Ladies',
#  'The Big Bang Theory',
#  'Kip Thorne',
#  'Courtney Henggeler',
#  'Brian Greene',
#  'The Stag Convergence',
#  'The Friendship Algorithm',
#  'John Ross Bowie',
#  'Raj',
#  'Carol Ann Susi',
#  'Claire',
#  'Rajesh',
#  'David Saltzberg',
#  'Katee Sackhoff',
#  'Brian George',
#  'Mary T. Quigley',
#  'Kunal Nayyar',
#  'Kripke Krippler',
#  'Stuart Bloom',
#  'Anu',
#  'George Smoot',
#  'Mike Massimino',
#  'Anthony Rich',
#  'Alfred Hofstadter',
#  'Mike Rostenkowski',
#  'The Helium Insufficiency',
#  'Brian Posehn',
#  'Wil Wheaton',
#  'Brian Thomas Smith',
#  'Janine Davis',
#  'Stephen Merchant',
#  'Charlie Sheen',
#  'Stephen Hawking',
#  'Kate Micucci',
#  'Mark Hamill',
#  'Simon Helberg',
#  'Althea Davis',
#  'The Perspiration Implementation',
#  'Kevin Smith',
#  'Steven V. Silver',
#  'William Shatner',
#  'German',
#  'Bill Nye',
#  'Matt Bennett',
#  'LeVar Burton',
#  'Penny Hofstadter',
#  'Casey Sander',
#  'Dave Goetsch',
#  'Professor Proton',
#  'The Comic Book Store Regeneration',
#  'Halley Wolowitz',
#  'Johnny Galecki',
#  'The Plagiarism\ufeff\ufeff\ufeff \ufeffSchism\ufeff\ufeff\ufeff\ufeff\ufeff\ufeff',
#  'Josh Wolowitz',
#  'The Toast Derivation',
#  'Howard',
#  'Howard Wolowitz',
#  'Steve Holland',
#  'Siri',
#  'Rajesh Koothrappali']

# %%
# order the list
tag_list.sort()
print('Size of \'tag_list\':', len(tag_list))
tag_list
# Out:
# Size of 'tag_list': 197
# ['Aarti Mann',
#  'Adam West',
#  'Alessandra Torresani',
#  'Alex Jensen',
#  'Alfred Hofstadter',
#  'Alice Amter',
#  'Althea Davis',
#  'Amy',
#  'Amy Farrah Fowler',
#  'Anthony Del Broccolo',
#  'Anthony Rich',
#  'Anu',
#  'Apartment 4A',
#  'Barenaked Ladies',
#  'Bernadette Rostenkowski-Wolowitz',
#  'Bert Kibbler',
#  'Beverly Hofstadter',
#  'Bill Nye',
#  'Bill Prady',
#  'Brent Spiner',
#  'Brian George',
#  'Brian Greene',
#  'Brian Patrick Wade',
#  'Brian Posehn',
#  'Brian Thomas Smith',
#  'Buzz Aldrin',
#  'Caltech',
#  'Carol Ann Susi',
#  'Carrie Fisher',
#  'Casey Sander',
#  'Charlie Sheen',
#  'Christine Baranski',
#  'Chuck Lorre',
#  'Chuck Lorre Productions',
#  'Cinnamon',
#  'Claire',
#  'Colonel Richard Williams',
#  'Courtney Henggeler',
#  'Dan',
#  'Dave Goetsch',
#  'David Gibbs',
#  'David Saltzberg',
#  'Dean Norris',
#  'Debbie Melvina Wolowitz',
#  'Denise',
#  'Dennis Kim',
#  'Dimitri',
#  'Dr. Pemberton',
#  'Emily Sweeney',
#  'Eric Gablehauser',
#  'Eric Kaplan',
#  'Fun with Flags',
#  'George Cooper Jr.',
#  'George Cooper Sr.',
#  'George Smoot',
#  'George Takei',
#  'German',
#  'Halley Wolowitz',
#  'Howard',
#  'Howard Wolowitz',
#  'Howie Mandel',
#  'Jack McBrayer',
#  'James Burrows',
#  'James Earl Jones',
#  'Janine Davis',
#  'Jeanie',
#  "Jerry O'Connell",
#  'Jim Parsons',
#  'Jim Reynolds',
#  'Jimmy Speckerman',
#  'Joe Manganiello',
#  'John Ross Bowie',
#  'Johnny Galecki',
#  'Josh Wolowitz',
#  'Joshua Malina',
#  'Judd Hirsch',
#  'June Squibb',
#  'Kaley Cuoco',
#  'Kara Luiz',
#  'Kareem Abdul-Jabbar',
#  'Kate Micucci',
#  'Katee Sackhoff',
#  'Katey Sagal',
#  'Keith Carradine',
#  'Kevin Smith',
#  'Kevin Sussman',
#  'Kip Thorne',
#  'Kripke Krippler',
#  'Kunal Nayyar',
#  'Kurt',
#  'Larry Fowler',
#  'Laura Spencer',
#  'Laurie Metcalf',
#  'LeVar Burton',
#  'Lee Aronsohn',
#  'Leonard',
#  'Leonard Hofstadter',
#  'Leslie Winkle',
#  'Lucy',
#  'M.O.N.T.E.',
#  'Margo Harshman',
#  'Maria Ferrari',
#  'Marissa',
#  'Mark Cendrowski',
#  'Mark Hamill',
#  'Mark Harelik',
#  'Mary Cooper',
#  'Mary T. Quigley',
#  'Matt Bennett',
#  'Mayim Bialik',
#  'Meagen Fay',
#  'Meemaw',
#  'Melissa Rauch',
#  'Mike Massimino',
#  'Mike Rostenkowski',
#  'Missy Cooper',
#  'Mrs. Koothrappali',
#  'Mrs. Rostenkowski',
#  'Neil Michael Wolowitz',
#  'Neil deGrasse Tyson',
#  'Penny',
#  'Penny Hofstadter',
#  'Peter Chakos',
#  'President Siebert',
#  'Priya Koothrappali',
#  'Professor Proton',
#  'Professor Rothman',
#  'Raj',
#  "Raj's apartment",
#  'Rajesh',
#  'Rajesh Koothrappali',
#  'Ramona Nowitzki',
#  'Randall',
#  'Regina King',
#  'Richard Rosenstock',
#  'Sara Gilbert',
#  'Sara Rue',
#  'Sarah Michelle Gellar',
#  'Shamy',
#  'Sheldon',
#  'Sheldon Cooper',
#  'Sheldon Cooper presents Fun with Flags',
#  'Sheldon and Amy',
#  "Sheldon's office",
#  'Simon Helberg',
#  'Siri',
#  'Stan Lee',
#  'Star Trek',
#  'Stephanie Barnett',
#  'Stephen Hawking',
#  'Stephen Merchant',
#  'Steve Holland',
#  'Steve Wozniak',
#  'Steven Molaro',
#  'Steven V. Silver',
#  'String theory',
#  'Stuart Bloom',
#  'Summer Glau',
#  'Susan',
#  'Tara Hernandez',
#  'Template talk:Characterf',
#  'Template:Characterf',
#  'The Allowance Evaporation',
#  'The Athenaeum Allocation',
#  'The Beta Test Initiation',
#  'The Big Bang Theory',
#  'The Bow Tie Asymmetry',
#  'The Cafeteria',
#  'The Celebration Experimentation',
#  'The Champagne Reflection',
#  'The Change Constant',
#  'The Comic Book Store Regeneration',
#  'The Cooper/Kripke Inversion',
#  'The Discovery Dissipation',
#  'The Electric Can Opener Fluctuation',
#  'The Friendship Algorithm',
#  'The Geology Elevation',
#  'The Grant Allocation Derivation',
#  'The Helium Insufficiency',
#  'The History of Everything',
#  'The Killer Robot Instability',
#  'The Perspiration Implementation',
#  'The Plagiarism\ufeff\ufeff\ufeff \ufeffSchism\ufeff\ufeff\ufeff\ufeff\ufeff\ufeff',
#  'The Relationship Diremption',
#  'The Rothman Disintegration',
#  'The Social Group',
#  'The Stag Convergence',
#  'The Tenure Turbulence',
#  'The Tesla Recoil',
#  'The Toast Derivation',
#  'The Valentino Submergence',
#  'The Vengeance Formulation',
#  'V. M. Koothrappali',
#  'Wil Wheaton',
#  'William Shatner',
#  'Wyatt',
#  'Zack Johnson']

# %% [markdown]
# ### Create a filter for unwanted types of articles

# %%
filter  = '(%s)' % '|'.join([
    'The '
])
# remove the links that are found in the filter
tag_list = [t for t in tag_list if not re.search(filter, t)]
print('Size of \'tag_list\':', len(tag_list))
tag_list
# Out:
# Size of 'tag_list': 167
# ['Aarti Mann',
#  'Adam West',
#  'Alessandra Torresani',
#  'Alex Jensen',
#  'Alfred Hofstadter',
#  'Alice Amter',
#  'Althea Davis',
#  'Amy',
#  'Amy Farrah Fowler',
#  'Anthony Del Broccolo',
#  'Anthony Rich',
#  'Anu',
#  'Apartment 4A',
#  'Barenaked Ladies',
#  'Bernadette Rostenkowski-Wolowitz',
#  'Bert Kibbler',
#  'Beverly Hofstadter',
#  'Bill Nye',
#  'Bill Prady',
#  'Brent Spiner',
#  'Brian George',
#  'Brian Greene',
#  'Brian Patrick Wade',
#  'Brian Posehn',
#  'Brian Thomas Smith',
#  'Buzz Aldrin',
#  'Caltech',
#  'Carol Ann Susi',
#  'Carrie Fisher',
#  'Casey Sander',
#  'Charlie Sheen',
#  'Christine Baranski',
#  'Chuck Lorre',
#  'Chuck Lorre Productions',
#  'Cinnamon',
#  'Claire',
#  'Colonel Richard Williams',
#  'Courtney Henggeler',
#  'Dan',
#  'Dave Goetsch',
#  'David Gibbs',
#  'David Saltzberg',
#  'Dean Norris',
#  'Debbie Melvina Wolowitz',
#  'Denise',
#  'Dennis Kim',
#  'Dimitri',
#  'Dr. Pemberton',
#  'Emily Sweeney',
#  'Eric Gablehauser',
#  'Eric Kaplan',
#  'Fun with Flags',
#  'George Cooper Jr.',
#  'George Cooper Sr.',
#  'George Smoot',
#  'George Takei',
#  'German',
#  'Halley Wolowitz',
#  'Howard',
#  'Howard Wolowitz',
#  'Howie Mandel',
#  'Jack McBrayer',
#  'James Burrows',
#  'James Earl Jones',
#  'Janine Davis',
#  'Jeanie',
#  "Jerry O'Connell",
#  'Jim Parsons',
#  'Jim Reynolds',
#  'Jimmy Speckerman',
#  'Joe Manganiello',
#  'John Ross Bowie',
#  'Johnny Galecki',
#  'Josh Wolowitz',
#  'Joshua Malina',
#  'Judd Hirsch',
#  'June Squibb',
#  'Kaley Cuoco',
#  'Kara Luiz',
#  'Kareem Abdul-Jabbar',
#  'Kate Micucci',
#  'Katee Sackhoff',
#  'Katey Sagal',
#  'Keith Carradine',
#  'Kevin Smith',
#  'Kevin Sussman',
#  'Kip Thorne',
#  'Kripke Krippler',
#  'Kunal Nayyar',
#  'Kurt',
#  'Larry Fowler',
#  'Laura Spencer',
#  'Laurie Metcalf',
#  'LeVar Burton',
#  'Lee Aronsohn',
#  'Leonard',
#  'Leonard Hofstadter',
#  'Leslie Winkle',
#  'Lucy',
#  'M.O.N.T.E.',
#  'Margo Harshman',
#  'Maria Ferrari',
#  'Marissa',
#  'Mark Cendrowski',
#  'Mark Hamill',
#  'Mark Harelik',
#  'Mary Cooper',
#  'Mary T. Quigley',
#  'Matt Bennett',
#  'Mayim Bialik',
#  'Meagen Fay',
#  'Meemaw',
#  'Melissa Rauch',
#  'Mike Massimino',
#  'Mike Rostenkowski',
#  'Missy Cooper',
#  'Mrs. Koothrappali',
#  'Mrs. Rostenkowski',
#  'Neil Michael Wolowitz',
#  'Neil deGrasse Tyson',
#  'Penny',
#  'Penny Hofstadter',
#  'Peter Chakos',
#  'President Siebert',
#  'Priya Koothrappali',
#  'Professor Proton',
#  'Professor Rothman',
#  'Raj',
#  "Raj's apartment",
#  'Rajesh',
#  'Rajesh Koothrappali',
#  'Ramona Nowitzki',
#  'Randall',
#  'Regina King',
#  'Richard Rosenstock',
#  'Sara Gilbert',
#  'Sara Rue',
#  'Sarah Michelle Gellar',
#  'Shamy',
#  'Sheldon',
#  'Sheldon Cooper',
#  'Sheldon Cooper presents Fun with Flags',
#  'Sheldon and Amy',
#  "Sheldon's office",
#  'Simon Helberg',
#  'Siri',
#  'Stan Lee',
#  'Star Trek',
#  'Stephanie Barnett',
#  'Stephen Hawking',
#  'Stephen Merchant',
#  'Steve Holland',
#  'Steve Wozniak',
#  'Steven Molaro',
#  'Steven V. Silver',
#  'String theory',
#  'Stuart Bloom',
#  'Summer Glau',
#  'Susan',
#  'Tara Hernandez',
#  'Template talk:Characterf',
#  'Template:Characterf',
#  'V. M. Koothrappali',
#  'Wil Wheaton',
#  'William Shatner',
#  'Wyatt',
#  'Zack Johnson']

# %% [markdown]
# >

# %% [markdown]
# >

# %% [markdown]
# >

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Data Science Institute of Australia
#
#
# ---
#
#
#
# ---
