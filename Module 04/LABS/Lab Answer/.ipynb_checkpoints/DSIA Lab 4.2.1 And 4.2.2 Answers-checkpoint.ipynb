# %% [markdown]
# ![alt text](https://i.imgur.com/1WaY7aA.png)

# %% [markdown]
# # Black Cat Data - Data Science and AI
# ## Lab 4.2.1: Feature Selection

# %% [markdown]
# ### 1. Load & Explore Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Read CSV
wine = pd.read_csv('winequality_merged.csv')

# %%
# Shape
wine.shape
# Out:
# (6497, 13)

# %%
# Head
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  red_wine
# 0      9.4        5         1
# 1      9.8        5         1
# 2      9.8        5         1
# 3      9.8        6         1
# 4      9.4        5         1

# %%
# Tail
wine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  red_wine
# 6492     11.2        6         0
# 6493      9.6        5         0
# 6494      9.4        6         0
# 6495     12.8        7         0
# 6496     11.8        6         0

# %%
# Check Nulls
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# red_wine                0
# dtype: int64

# %%
# Data Types
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
# fixed acidity           6497 non-null float64
# volatile acidity        6497 non-null float64
# citric acid             6497 non-null float64
# residual sugar          6497 non-null float64
# chlorides               6497 non-null float64
# free sulfur dioxide     6497 non-null float64
# total sulfur dioxide    6497 non-null float64
# density                 6497 non-null float64
# pH                      6497 non-null float64
# sulphates               6497 non-null float64
# alcohol                 6497 non-null float64
# quality                 6497 non-null int64
# red_wine                6497 non-null int64
# dtypes: float64(11), int64(2)
# memory usage: 659.9 KB

# %%
# Pairplot
sns.pairplot(wine)

# %%
# Correlation
wine_corr = wine.corr()
wine_corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
# red_wine                   0.486740          0.653036    -0.187397
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.111981   0.298195            -0.282735
# volatile acidity           -0.196011   0.377124            -0.352557
# citric acid                 0.142451   0.038998             0.133126
# residual sugar              1.000000  -0.128940             0.402871
# chlorides                  -0.128940   1.000000            -0.195045
# free sulfur dioxide         0.402871  -0.195045             1.000000
# total sulfur dioxide        0.495482  -0.279630             0.720934
# density                     0.552517   0.362615             0.025717
# pH                         -0.267320   0.044708            -0.145854
# sulphates                  -0.185927   0.395593            -0.188457
# alcohol                    -0.359415  -0.256916            -0.179838
# quality                    -0.036980  -0.200666             0.055463
# red_wine                   -0.348821   0.512678            -0.471644
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.329054  0.458910 -0.252700   0.299568
# volatile acidity                 -0.414476  0.271296  0.261454   0.225984
# citric acid                       0.195242  0.096154 -0.329808   0.056197
# residual sugar                    0.495482  0.552517 -0.267320  -0.185927
# chlorides                        -0.279630  0.362615  0.044708   0.395593
# free sulfur dioxide               0.720934  0.025717 -0.145854  -0.188457
# total sulfur dioxide              1.000000  0.032395 -0.238413  -0.275727
# density                           0.032395  1.000000  0.011686   0.259478
# pH                               -0.238413  0.011686  1.000000   0.192123
# sulphates                        -0.275727  0.259478  0.192123   1.000000
# alcohol                          -0.265740 -0.686745  0.121248  -0.003029
# quality                          -0.041385 -0.305858  0.019506   0.038485
# red_wine                         -0.700357  0.390645  0.329129   0.487218
#
#                        alcohol   quality  red_wine
# fixed acidity        -0.095452 -0.076743  0.486740
# volatile acidity     -0.037640 -0.265699  0.653036
# citric acid          -0.010493  0.085532 -0.187397
# residual sugar       -0.359415 -0.036980 -0.348821
# chlorides            -0.256916 -0.200666  0.512678
# free sulfur dioxide  -0.179838  0.055463 -0.471644
# total sulfur dioxide -0.265740 -0.041385 -0.700357
# density              -0.686745 -0.305858  0.390645
# pH                    0.121248  0.019506  0.329129
# sulphates            -0.003029  0.038485  0.487218
# alcohol               1.000000  0.444319 -0.032970
# quality               0.444319  1.000000 -0.119323
# red_wine             -0.032970 -0.119323  1.000000

# %%
# Copied code from seaborn examples
# https://seaborn.pydata.org/examples/many_pairwise_correlations.html
sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.zeros_like(wine_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(wine_corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.show();

# %% [markdown]
# ### 2. Set Target Variable

# %% [markdown]
# Create a target variable for wine quality.

# %%
# Target Variable
y = wine['quality']

# %% [markdown]
# ### 3. Set Predictor Variables

# %% [markdown]
# Create a predictor matrix with variables of your choice.

# %%
# Check correlation
wine.corr()['quality'].sort_values()
# Out:
# density                -0.305858
# volatile acidity       -0.265699
# chlorides              -0.200666
# red_wine               -0.119323
# fixed acidity          -0.076743
# total sulfur dioxide   -0.041385
# residual sugar         -0.036980
# pH                      0.019506
# sulphates               0.038485
# free sulfur dioxide     0.055463
# citric acid             0.085532
# alcohol                 0.444319
# quality                 1.000000
# Name: quality, dtype: float64

# %%
# I chose the feature which are strogly correalted with quality
predictor_columns = ['density', 'volatile acidity', 'chlorides', 'alcohol']

# %%
X = wine[predictor_columns]
X.head()
# Out:
#    density  volatile acidity  chlorides  alcohol
# 0   0.9978              0.70      0.076      9.4
# 1   0.9968              0.88      0.098      9.8
# 2   0.9970              0.76      0.092      9.8
# 3   0.9980              0.28      0.075      9.8
# 4   0.9978              0.70      0.076      9.4

# %% [markdown]
# ### 4. Using Linear Regression Create a Model and Test Score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Train-Test Split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_train, y_train)
# Out:
# 0.2707886547599643

# %%
lr.score(X_test, y_test)
# Out:
# 0.2521354751304956

# %% [markdown]
# ### 5. Forward Feature Selection
#
# > Forward Selection: Forward selection is an iterative method in which we start with having no feature in the model. In each iteration, we keep adding the feature which best improves our model till an addition of a new variable does not improve the performance of the model.
#
# Create a Regression model using Forward Feature Selection by looping over all the features adding one at a time until there are no improvements on the prediction metric ( R2  and  AdjustedR2  in this case).

# %% [markdown]
# #### 5.1 Load Wine Data & Define Predictor and Target

# %%
## Load the Diabetes Housing dataset

# Load the wine dataset from csv
wine = pd.read_csv('winequality_merged.csv')

# define the target variable (dependent variable) as y
y = wine['quality']

# Take all columns except target as predictor columns
predictor_columns = [c for c in wine.columns if c != 'quality']
# Load the dataset as a pandas data frame
X = pd.DataFrame(wine, columns = predictor_columns)

# %%
## Create training and testing subsets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# #### 5.2 Overview of the code below
#
# The external `while` loop goes forever until there are no improvements to the model, which is controlled by the flag `changed` (until is **not** changed).
# The inner `for` loop goes over each of the features not yet included in the model and calculates the correlation coefficient. If any model improves on the previous best model then the records are updated.
#
# #### Code variables
# - `included`: list of the features (predictors) that were included in the model; starts empty.
# - `excluded`: list of features that have **not** been included in the model; starts as the full list of features.
# - `best`: dictionary to keep record of the best model found at any stage; starts 'empty'.
# - `model`: object of class LinearRegression, with default values for all parameters.
#
# #### Methods of the `LinearRegression` object to investigate
# - `fit()`
# - `fit.score()`
#
# #### Adjusted $R^2$ formula
# $$Adjusted \; R^2 = 1 - { (1 - R^2) (n - 1)  \over n - k - 1 }$$
#
# #### Linear Regression [reference](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)

# %%
## Flag intermediate output

show_steps = True   # for testing/debugging
# show_steps = False  # without showing steps

# %%
X_train.shape[0]
# Out:
# 5197

# %%
## Use Forward Feature Selection to pick a good model

# start with no predictors
included = []
# keep track of model and parameters
best = {'feature': '', 'r2': 0, 'a_r2': 0}
# create a model object to hold the modelling parameters
model = LinearRegression()
# get the number of cases in the test data
n = X_test.shape[0]

while True:
    changed = False
    
    if show_steps:
        print('') 

    # list the features to be evaluated
    excluded = list(set(X.columns) - set(included))
    
    if show_steps:
        print('(Step) Excluded = %s' % ', '.join(excluded))  

    # for each remaining feature to be evaluated
    for new_column in excluded:
        
        if show_steps:
            print('(Step) Trying %s...' % new_column)
            print('(Step) - Features = %s' % ', '.join(included + [new_column]))

        # fit the model with the Training data
        fit = model.fit(X_train[included + [new_column]], y_train)
        # calculate the score (R^2 for Regression)
        r2 = fit.score(X_train[included + [new_column]], y_train)
        # number of predictors in this model
        k = len(included) + 1
        # calculate the adjusted R^2
        adjusted_r2 = 1 - ( ( (1 - r2) * (n - 1) ) / (n - k - 1) )

        if show_steps:
            print('(Step) - Adjusted R^2: This = %.3f; Best = %.3f' % 
                  (adjusted_r2, best['a_r2']))

        # if model improves
        if adjusted_r2 > best['a_r2']:
            # record new parameters
            best = {'feature': new_column, 'r2': r2, 'a_r2': adjusted_r2}
            # flag that found a better model
            changed = True
            if show_steps:
                print('(Step) - New Best!   : Feature = %s; R^2 = %.3f; Adjusted R^2 = %.3f' % 
                      (best['feature'], best['r2'], best['a_r2']))
    # END for

    # if found a better model after testing all remaining features
    if changed:
        # update control details
        included.append(best['feature'])
        excluded = list(set(excluded) - set(best['feature']))
        print('Added feature %-4s with R^2 = %.3f and adjusted R^2 = %.3f' % 
              (best['feature'], best['r2'], best['a_r2']))
    else:
        # terminate if no better model
        print('*'*50)
        break

print('')
print('Resulting features:')
print(', '.join(included))
# Out:
# (Step) Excluded = alcohol, chlorides, pH, citric acid, residual sugar, total sulfur dioxide, red_wine, density, fixed acidity, volatile acidity, free sulfur dioxide, sulphates
# (Step) Trying alcohol...
# (Step) - Features = alcohol
# (Step) - Adjusted R^2: This = 0.197; Best = 0.000
# (Step) - New Best!   : Feature = alcohol; R^2 = 0.197; Adjusted R^2 = 0.197
# (Step) Trying chlorides...
# (Step) - Features = chlorides
# (Step) - Adjusted R^2: This = 0.036; Best = 0.197
# (Step) Trying pH...
# (Step) - Features = pH
# (Step) - Adjusted R^2: This = -0.000; Best = 0.197
# (Step) Trying citric acid...
# (Step) - Features = citric acid
# (Step) - Adjusted R^2: This = 0.007; Best = 0.197
# (Step) Trying residual sugar...
# (Step) - Features = residual sugar
# (Step) - Adjusted R^2: This = 0.000; Best = 0.197
# (Step) Trying total sulfur dioxide...
# (Step) - Features = total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.001; Best = 0.197
# (Step) Trying red_wine...
# (Step) - Features = red_wine
# (Step) - Adjusted R^2: This = 0.014; Best = 0.197
# (Step) Trying density...
# (Step) - Features = density
# (Step) - Adjusted R^2: This = 0.092; Best = 0.197
# (Step) Trying fixed acidity...
# (Step) - Features = fixed acidity
# (Step) - Adjusted R^2: This = 0.006; Best = 0.197
# (Step) Trying volatile acidity...
# (Step) - Features = volatile acidity
# (Step) - Adjusted R^2: This = 0.068; Best = 0.197
# (Step) Trying free sulfur dioxide...
# (Step) - Features = free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.003; Best = 0.197
# (Step) Trying sulphates...
# (Step) - Features = sulphates
# (Step) - Adjusted R^2: This = 0.000; Best = 0.197
# Added feature alcohol with R^2 = 0.197 and adjusted R^2 = 0.197
#
# (Step) Excluded = chlorides, pH, citric acid, residual sugar, total sulfur dioxide, red_wine, density, fixed acidity, volatile acidity, free sulfur dioxide, sulphates
# (Step) Trying chlorides...
# (Step) - Features = alcohol, chlorides
# (Step) - Adjusted R^2: This = 0.203; Best = 0.197
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.204; Adjusted R^2 = 0.203
# (Step) Trying pH...
# (Step) - Features = alcohol, pH
# (Step) - Adjusted R^2: This = 0.197; Best = 0.203
# (Step) Trying citric acid...
# (Step) - Features = alcohol, citric acid
# (Step) - Adjusted R^2: This = 0.205; Best = 0.203
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.206; Adjusted R^2 = 0.205
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, residual sugar
# (Step) - Adjusted R^2: This = 0.215; Best = 0.205
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.217; Adjusted R^2 = 0.215
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.203; Best = 0.215
# (Step) Trying red_wine...
# (Step) - Features = alcohol, red_wine
# (Step) - Adjusted R^2: This = 0.208; Best = 0.215
# (Step) Trying density...
# (Step) - Features = alcohol, density
# (Step) - Adjusted R^2: This = 0.196; Best = 0.215
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, fixed acidity
# (Step) - Adjusted R^2: This = 0.198; Best = 0.215
# (Step) Trying volatile acidity...
# (Step) - Features = alcohol, volatile acidity
# (Step) - Adjusted R^2: This = 0.256; Best = 0.215
# (Step) - New Best!   : Feature = volatile acidity; R^2 = 0.257; Adjusted R^2 = 0.256
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.217; Best = 0.256
# (Step) Trying sulphates...
# (Step) - Features = alcohol, sulphates
# (Step) - Adjusted R^2: This = 0.197; Best = 0.256
# Added feature volatile acidity with R^2 = 0.257 and adjusted R^2 = 0.256
#
# (Step) Excluded = chlorides, pH, citric acid, residual sugar, total sulfur dioxide, red_wine, density, fixed acidity, free sulfur dioxide, sulphates
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, chlorides
# (Step) - Adjusted R^2: This = 0.256; Best = 0.256
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, pH
# (Step) - Adjusted R^2: This = 0.257; Best = 0.256
# (Step) - New Best!   : Feature = pH; R^2 = 0.258; Adjusted R^2 = 0.257
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, citric acid
# (Step) - Adjusted R^2: This = 0.255; Best = 0.257
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, residual sugar
# (Step) - Adjusted R^2: This = 0.263; Best = 0.257
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.264; Adjusted R^2 = 0.263
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.256; Best = 0.263
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, red_wine
# (Step) - Adjusted R^2: This = 0.260; Best = 0.263
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, density
# (Step) - Adjusted R^2: This = 0.263; Best = 0.263
# (Step) - New Best!   : Feature = density; R^2 = 0.265; Adjusted R^2 = 0.263
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, fixed acidity
# (Step) - Adjusted R^2: This = 0.256; Best = 0.263
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.259; Best = 0.263
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, sulphates
# (Step) - Adjusted R^2: This = 0.264; Best = 0.263
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.266; Adjusted R^2 = 0.264
# Added feature sulphates with R^2 = 0.266 and adjusted R^2 = 0.264
#
# (Step) Excluded = chlorides, citric acid, residual sugar, total sulfur dioxide, red_wine, density, fixed acidity, pH, free sulfur dioxide
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, chlorides
# (Step) - Adjusted R^2: This = 0.264; Best = 0.264
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.267; Adjusted R^2 = 0.264
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, citric acid
# (Step) - Adjusted R^2: This = 0.264; Best = 0.264
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar
# (Step) - Adjusted R^2: This = 0.274; Best = 0.264
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.276; Adjusted R^2 = 0.274
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.264; Best = 0.274
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, red_wine
# (Step) - Adjusted R^2: This = 0.265; Best = 0.274
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, density
# (Step) - Adjusted R^2: This = 0.268; Best = 0.274
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, fixed acidity
# (Step) - Adjusted R^2: This = 0.264; Best = 0.274
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, pH
# (Step) - Adjusted R^2: This = 0.264; Best = 0.274
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.269; Best = 0.274
# Added feature residual sugar with R^2 = 0.276 and adjusted R^2 = 0.274
#
# (Step) Excluded = chlorides, citric acid, total sulfur dioxide, red_wine, density, fixed acidity, pH, free sulfur dioxide
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, chlorides
# (Step) - Adjusted R^2: This = 0.274; Best = 0.274
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, citric acid
# (Step) - Adjusted R^2: This = 0.274; Best = 0.274
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.277; Adjusted R^2 = 0.274
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.276; Best = 0.274
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.279; Adjusted R^2 = 0.276
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine
# (Step) - Adjusted R^2: This = 0.277; Best = 0.276
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.280; Adjusted R^2 = 0.277
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, density
# (Step) - Adjusted R^2: This = 0.274; Best = 0.277
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, fixed acidity
# (Step) - Adjusted R^2: This = 0.274; Best = 0.277
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, pH
# (Step) - Adjusted R^2: This = 0.275; Best = 0.277
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.275; Best = 0.277
# Added feature red_wine with R^2 = 0.280 and adjusted R^2 = 0.277
#
# (Step) Excluded = chlorides, citric acid, total sulfur dioxide, density, fixed acidity, pH, free sulfur dioxide
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, chlorides
# (Step) - Adjusted R^2: This = 0.278; Best = 0.277
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.281; Adjusted R^2 = 0.278
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, citric acid
# (Step) - Adjusted R^2: This = 0.278; Best = 0.278
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.281; Adjusted R^2 = 0.278
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.277; Best = 0.278
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density
# (Step) - Adjusted R^2: This = 0.281; Best = 0.278
# (Step) - New Best!   : Feature = density; R^2 = 0.285; Adjusted R^2 = 0.281
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, fixed acidity
# (Step) - Adjusted R^2: This = 0.278; Best = 0.281
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, pH
# (Step) - Adjusted R^2: This = 0.278; Best = 0.281
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.281; Best = 0.281
# Added feature density with R^2 = 0.285 and adjusted R^2 = 0.281
#
# (Step) Excluded = chlorides, citric acid, total sulfur dioxide, fixed acidity, pH, free sulfur dioxide
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides
# (Step) - Adjusted R^2: This = 0.281; Best = 0.281
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.285; Adjusted R^2 = 0.281
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, citric acid
# (Step) - Adjusted R^2: This = 0.281; Best = 0.281
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.281; Best = 0.281
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, fixed acidity
# (Step) - Adjusted R^2: This = 0.281; Best = 0.281
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, pH
# (Step) - Adjusted R^2: This = 0.282; Best = 0.281
# (Step) - New Best!   : Feature = pH; R^2 = 0.286; Adjusted R^2 = 0.282
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.284; Best = 0.282
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.288; Adjusted R^2 = 0.284
# Added feature free sulfur dioxide with R^2 = 0.288 and adjusted R^2 = 0.284
#
# (Step) Excluded = chlorides, citric acid, total sulfur dioxide, fixed acidity, pH
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, chlorides
# (Step) - Adjusted R^2: This = 0.284; Best = 0.284
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.288; Adjusted R^2 = 0.284
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.283; Best = 0.284
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.286; Best = 0.284
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.290; Adjusted R^2 = 0.286
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.284; Best = 0.286
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.285; Best = 0.286
# Added feature total sulfur dioxide with R^2 = 0.290 and adjusted R^2 = 0.286
#
# (Step) Excluded = citric acid, fixed acidity, pH, chlorides
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.285; Best = 0.286
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.286; Best = 0.286
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.287; Best = 0.286
# (Step) - New Best!   : Feature = pH; R^2 = 0.292; Adjusted R^2 = 0.287
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, chlorides
# (Step) - Adjusted R^2: This = 0.286; Best = 0.287
# Added feature pH   with R^2 = 0.292 and adjusted R^2 = 0.287
#
# (Step) Excluded = citric acid, fixed acidity, chlorides
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, pH, citric acid
# (Step) - Adjusted R^2: This = 0.286; Best = 0.287
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, pH, fixed acidity
# (Step) - Adjusted R^2: This = 0.290; Best = 0.287
# (Step) - New Best!   : Feature = fixed acidity; R^2 = 0.295; Adjusted R^2 = 0.290
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, pH, chlorides
# (Step) - Adjusted R^2: This = 0.287; Best = 0.290
# Added feature fixed acidity with R^2 = 0.295 and adjusted R^2 = 0.290
#
# (Step) Excluded = citric acid, chlorides
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, pH, fixed acidity, citric acid
# (Step) - Adjusted R^2: This = 0.289; Best = 0.290
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, pH, fixed acidity, chlorides
# (Step) - Adjusted R^2: This = 0.290; Best = 0.290
# **************************************************
#
# Resulting features:
# alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, pH, fixed acidity
