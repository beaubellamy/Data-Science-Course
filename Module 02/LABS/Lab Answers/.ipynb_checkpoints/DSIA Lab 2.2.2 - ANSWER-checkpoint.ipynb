# %% [markdown]
# ![alt text](https://i.imgur.com/1WaY7aA.png)
#
# ---
#
#
#
# ---

# %% [markdown]
# # Lab 2.2.2
# # *Mining Social Media with Twitter*

# %% [markdown]
# ## The Twitter API and Tweepy Package

# %% [markdown]
# The Twitter API provides access to tweets and comments, and allows an application to post tweets to the user's timeline.
#
# Twitter requires developers to create and authenticate an app before they can use the API. As of recent policy changes, however, new developers must be approved before they can create an app. There is no indication of the waiting period for approval.

# %% [markdown]
# ### 1. Apply for Developer Access
#
# Go to https://blog.twitter.com/developer/en_us/topics/tools/2018/new-developer-requirements-to-protect-our-platform.html
# and read the advice.
# ![image.png](attachment:image.png)

# %% [markdown]
# Apply at https://developer.twitter.com/en/apply-for-access.html
# ![image.png](attachment:image.png)

# %% [markdown]
# Then go to https://developer.twitter.com/en/review every day until you see whatever comes after this:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Create Your Twitter App
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Load Python Libraries

# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading https://files.pythonhosted.org/packages/d5/5f/daac4b4e9b30d7d2a6fdd16a880ff79f27918fe388e4dfc1983dec3a9876/tweepy-3.7.0-py2.py3-none-any.whl
# Collecting requests-oauthlib>=0.7.0 (from tweepy)
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from tweepy) (1.11.0)
# Requirement already satisfied: requests>=2.11.1 in c:\programdata\anaconda3\lib\site-packages (from tweepy) (2.18.4)
# Requirement already satisfied: PySocks>=1.5.7 in c:\programdata\anaconda3\lib\site-packages (from tweepy) (1.6.7)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->tweepy)
#   Downloading https://files.pythonhosted.org/packages/16/95/699466b05b72b94a41f662dc9edf87fda4289e3602ecd42d27fcaddf7b56/oauthlib-3.0.1-py2.py3-none-any.whl (142kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2019.3.9)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.0.1 requests-oauthlib-1.2.0 tweepy-3.7.0
# You are using pip version 19.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import tweepy
import json
import pprint

# %% [markdown]
# ### 4. Authenticate from your Python script

# %% [markdown]
# You could assign your authentication details explicitly, as follows:

# %%
my_consumer_key = 'GS7kRxkpveBFqpey6myCwJ01d'      # your consumer key (string) goes in here
my_consumer_secret = 'gGc9bnCGYQvjDY8M47foKmRSdl6FuFqmOIAOIJMn4M39rIlXUT'   # your consumer secret key (string) goes in here
my_access_token = '82147042-L7wiMqxZqib6XiLdpphwskaKGKfEjZfMw4mhEdMOr'      # your access token (string goes in here
access_token_secret = 'EZvfP55xXAmqymu3SpDL8yxVKVOe9DFYYFwfiaBbMWckW'  # your access token secret (string) goes in here

# %%
import json

auth_twitter_json = {
    'consumer_key': 'GS7kRxkpveBFqpey6myCwJ01d'      # your consumer key (string) goes in here
    , 'consumer_secret': 'gGc9bnCGYQvjDY8M47foKmRSdl6FuFqmOIAOIJMn4M39rIlXUT'   # your consumer secret key (string) goes in here
    , 'access_token': '82147042-L7wiMqxZqib6XiLdpphwskaKGKfEjZfMw4mhEdMOr'      # your access token (string goes in here
    , 'access_token_secret': 'EZvfP55xXAmqymu3SpDL8yxVKVOe9DFYYFwfiaBbMWckW'  # your access token secret (string) goes in here
}

with open('auth_twitter.json', 'w') as outfile:  
    json.dump(auth_twitter_json, outfile)

# %% [markdown]
# A better way would be to store these details externally, so they are not displayed in the notebook:
#
# - create a file called "auth_twitter.json" in your "notebooks" directory, and save your credentials there in JSON format:
#
# `{   "consumer_key": "your consumer key (string) goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;` "consumer_secret": "your consumer secret key (string) goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"access_token": "your access token (string) goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"access_token_secret": "your access token secret (string) goes in here"` <br>
# `}`
#
# (Nb. Parsers are very fussy. Make sure each key:value pair has a comma after it except the last one!)
#
# Use the following code to load the credentials:

# %%
pwd()  # make sure your working directory is where the file is
# Out:
# 'C:\\Users\\Faisal\\DSIA\\Data-Science-Curriculum\\Module 2\\LABS\\Lab Answers'

# %%
path_auth = 'auth_twitter.json'
auth = json.loads(open(path_auth).read())
pp = pprint.PrettyPrinter(indent=4)
# For debugging only:
pp.pprint(auth)
# Out:
# {   'access_token': '82147042-L7wiMqxZqib6XiLdpphwskaKGKfEjZfMw4mhEdMOr',
#     'access_token_secret': 'EZvfP55xXAmqymu3SpDL8yxVKVOe9DFYYFwfiaBbMWckW',
#     'consumer_key': 'GS7kRxkpveBFqpey6myCwJ01d',
#     'consumer_secret': 'gGc9bnCGYQvjDY8M47foKmRSdl6FuFqmOIAOIJMn4M39rIlXUT'}

# %%
my_consumer_key = auth['consumer_key']
my_consumer_secret = auth['consumer_secret']
my_access_token = auth['access_token']
my_access_token_secret = auth['access_token_secret']

# %% [markdown]
# Security considerations:
# - this method only keeps your credentials invisible as long as nobody accesses this notebook while it's running on your computer
# - if you wanted another user to have access to the executable notebook without divulging your credentials you should set up an OAuth 2.0 workflow to let them obtain and apply their own API tokens when using your app
# - if you just want to share your analyses, you could use a separate script (which you don't share) to fetch the data and save it locally, then use a second notebook (with no API access) to load and analyse the locally stored data

# %% [markdown]
# ### 5. Exploring the API

# %% [markdown]
# Here is how to connect to Twitter using the Tweepy library:

# %%
auth = tweepy.OAuthHandler(my_consumer_key, my_consumer_secret)
auth.set_access_token(my_access_token, my_access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# In the next cell, put the cursor after the '.' and hit the [tab] key to see the available members and methods in the response object:

# %%
api.followers()[0]._json
# Out:
# {'blocked_by': False,
#  'blocking': False,
#  'contributors_enabled': False,
#  'created_at': 'Thu Feb 28 16:38:11 +0000 2013',
#  'default_profile': True,
#  'default_profile_image': False,
#  'description': 'Humoristische blik op het nieuws. Is nogal woordspelig. Opmerkelijk nieuws. Satire, taal  & politiek. Tweets in Nederlands, English, Deutsch.',
#  'entities': {'description': {'urls': []}},
#  'favourites_count': 307,
#  'follow_request_sent': False,
#  'followers_count': 10572,
#  'following': False,
#  'friends_count': 11531,
#  'geo_enabled': True,
#  'has_extended_profile': False,
#  'id': 1227916478,
#  'id_str': '1227916478',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': 'nl',
#  'listed_count': 129,
#  'live_following': False,
#  'location': '',
#  'muting': False,
#  'name': 'actualiteitjunk',
#  'notifications': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1227916478/1416676901',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/3320126563/8bf0f7c7c8ab31cf843ccb7f014f493c_normal.png',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3320126563/8bf0f7c7c8ab31cf843ccb7f014f493c_normal.png',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'actualiteitjunk',
#  'status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Mar 29 08:59:29 +0000 2019',
#   'entities': {'hashtags': [{'indices': [0, 12], 'text': 'mindfulness'},
#     {'indices': [17, 26], 'text': 'huiswerk'},
#     {'indices': [27, 37], 'text': 'opvoeding'},
#     {'indices': [38, 46], 'text': 'mindful'}],
#    'media': [{'display_url': 'pic.twitter.com/JyxhuYPRyY',
#      'expanded_url': 'https://twitter.com/actualiteitjunk/status/1111553451450867712/photo/1',
#      'id': 1111553446732316674,
#      'id_str': '1111553446732316674',
#      'indices': [55, 78],
#      'media_url': 'http://pbs.twimg.com/media/D20H-HVXQAIXYo2.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D20H-HVXQAIXYo2.jpg',
#      'sizes': {'large': {'h': 891, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 891, 'resize': 'fit', 'w': 720},
#       'small': {'h': 680, 'resize': 'fit', 'w': 549},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/JyxhuYPRyY'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 612508656,
#      'id_str': '612508656',
#      'indices': [47, 54],
#      'name': 'van 9 tot 5',
#      'screen_name': 'van9t5'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/JyxhuYPRyY',
#      'expanded_url': 'https://twitter.com/actualiteitjunk/status/1111553451450867712/photo/1',
#      'id': 1111553446732316674,
#      'id_str': '1111553446732316674',
#      'indices': [55, 78],
#      'media_url': 'http://pbs.twimg.com/media/D20H-HVXQAIXYo2.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D20H-HVXQAIXYo2.jpg',
#      'sizes': {'large': {'h': 891, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 891, 'resize': 'fit', 'w': 720},
#       'small': {'h': 680, 'resize': 'fit', 'w': 549},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/JyxhuYPRyY'}]},
#   'favorite_count': 2,
#   'favorited': False,
#   'geo': None,
#   'id': 1111553451450867712,
#   'id_str': '1111553451450867712',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'und',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '#mindfulness....\n#huiswerk #opvoeding #mindful @van9t5 https://t.co/JyxhuYPRyY',
#   'truncated': False},
#  'statuses_count': 16745,
#  'time_zone': None,
#  'translator_type': 'none',
#  'url': None,
#  'utc_offset': None,
#  'verified': False}

# %% [markdown]
# Consult the Tweept and Twitter API documentation. Print a few of the response members below:

# %% [markdown]
# This will fetch recent tweets from accounts you follow:

# %%
# Recent tweets from accounts you follow:
tweets = api.home_timeline()
for tweet in tweets:
    print(tweet.text)
# Out:
# Southgate offers to help England women's team before World Cup https://t.co/V1B7Z16bJo https://t.co/yD1krSr2hr
# 1980s Beastie Boys in Times Square. Check out for more pics: https://t.co/Q2iDIpuPXE https://t.co/iBenwjlOJS
# golden gate bridge construction - unbelievably great photos. See more: https://t.co/gDhDYmM8Pc https://t.co/kkDfm4NOS2
# Another Gold for INDIA as KIRAR Muskan defeated MAT Salleh Fatin Nurfatehah in Gold medal match of Compound women… https://t.co/iLrsAgJg4v
# RT @SputnikInt: German government refuses to recognise @jguaido’s envoy as ambassador https://t.co/stDkyuTDko https://t.co/Hht8J6G5Eq
# Jamesph: [Flybuys] Collect 1 FREE Allen's Chews @ Coles https://t.co/nZTjdld82z
# Seeburg Select-O-Matic 100 Jukebox https://t.co/M9YujII433
# These temporary tattoos alert you when you've had too much sun https://t.co/D7cPD8A6pa
# 📝 André Onana has signed a contact extension at Ajax until 2022.
#
# #UCL https://t.co/6YjiqPW8uM
# RT @Partisangirl: Never forget how #Syria's christians fought Al Qaeda and ISIS on behalf of the world, and how American evangelists betray…
# Where will Smith and Warner fit in? Who should be left out? Should Australia tinker with a mostly settled line-up?… https://t.co/arN6mok9SW
# RT @UNFCCC: We are close to the moment where #ClimateChange will be irreversible. @WMO report shows that we need more #ClimateAmbition. I a…
# More than 90% of all jury trials in the world occur in the United States.
# RT @Stephenuk1: It's the FINAL of the 2019 World Cup of 70s &amp; 80s TV theme tunes! Choose from Test Match Special/Cricket or Dr Who to win t…
# Philippine news site chief and Duterte critic freed on bail after latest arrest https://t.co/iDGfrJjbeX https://t.co/EIUN8eCo92
# RT @prashantkawadia: Gurudev @SrBachchan Sir please look at this #AmitabhBachchan Ji Tatoo on @RajibMittra Ji's hand https://t.co/U3jLGWpsB7
# RT @VOANews: People across New Zealand observed the Muslim call to prayer on Friday as the nation reflected on the moment when 50 were kill…
# RT @JahidRahman: @usembassydhaka ঢাকার বনানীতে এফ আর টাওয়ারে ভয়াবহ অগ্নিকাণ্ডে হতাহতের ঘটনায় গভীর শোক ও  দুঃখ প্রকাশ করছি। নিহতদের আত্মা…
# France surrendered to Nazi Germany in 1940. Adolf Hitler and his sizable ego wanted the surrender to be signed in t… https://t.co/2jzFxaRsan
# RT @cricketkit: A few words of encouragement from an older, wiser, better spinner. Bhajji (615 white ball wickets at 30.14 with best of 5-1…

# %% [markdown]
# The request to see your own recent tweets is similar, but uses the `user_timeline` endpoint. Try this below:

# %%
#ANSWER:
# Your recent tweets:
tweets = api.user_timeline()
for tweet in tweets:
    print(tweet.text)
# Out:
# Best. https://t.co/sDJQBEEDfK
# #Mankading #SpiritOfTheGame #VIVOIPL #IPL2019 #AshwinMankads https://t.co/oTXAc6N23H
# If you are not ready to respect minorities in your country please don't insult Jacinda by appreciating her.
# RT @MichaelSkolnik: Six days after the terrorist attack in Christchurch, the New Zealand government has BANNED all semi-automatic weapons.…
# RT @VOANews: An emotional Haka was performed on Saturday, March 16, outside the Al Noor mosque in Christchurch, where 50 died in Friday's a…
# @StopFakeCases @memorable_90s Jayaprakash #Legend
# RT @Mahmudullah30: Alhamdulillah! Last night we got back to home safe &amp; sound. May the almighty Allah gives strength to those who lost thei…
# RT @PeteButtigieg: Some words for South Bend's Muslim community. https://t.co/CyLZOrah7b
# RT @Freedland: This isn’t about lone killers and deranged individuals. This is a terrorist movement of white supremacism that draws strengt…
# RT @philipdalidakis: An open offer to any Muslim man, woman or child. If you are fearful about walking through the gates of your mosque, le…
# RT @DennisCricket_: I'm ashamed that this is on Australian Government letterhead.
#
# That can only happen because enough Australians voted f…
# @arefinforbd #জ্ঞানীমানুষ
# RT @MominulHaque68: Terrifying to be so close to this tragic. May Allah give jannah to my innocent brothers. Wish we could all live peace i…
# RT @Angelo69Mathews: Schocked to hear about the new Zealand massacre.Thoughts and prayers with all those who are affected,relieved to hear…
# RT @MClarke23: Horrific news out of Christchurch! Absolutely devastating. Thoughts and prayers go out to all affected at this extremely sad…
# RT @ScottMorrisonMP: The remarks by Senator Fraser Anning blaming the murderous attacks by a violent, right-wing, extremist terrorist in Ne…
# RT @icelandcricket: Icelanders are praying for our Muslim brothers in Christchurch. https://t.co/imENHIoLb1
# RT @Uz_Khawaja: So saddened about the attacks in Christchurch today. My heart and duahs go out to all the victims and their families ❤️
# RT @AlanahEriksen: @rodemmerson https://t.co/68AyOCt8ff
# RT @joeburns441: My thoughts are with the people in Christchurch and Muslims around the world. @fraser_anning is an embarrassment to QLD &amp;…

# %% [markdown]
# Now, instead of printing the text of each tweet, print the `created_at` and `id_str` methods:

# %%
#ANSWER:
# tweets header info
tweets = api.user_timeline()
for tweet in tweets:
    print(tweet.created_at)
#     print(tweet.id_str)
    print(tweet.text)
# Out:
# 2019-03-27 20:30:30
# Best. https://t.co/sDJQBEEDfK
# 2019-03-26 04:28:31
# #Mankading #SpiritOfTheGame #VIVOIPL #IPL2019 #AshwinMankads https://t.co/oTXAc6N23H
# 2019-03-23 00:07:08
# If you are not ready to respect minorities in your country please don't insult Jacinda by appreciating her.
# 2019-03-21 05:39:52
# RT @MichaelSkolnik: Six days after the terrorist attack in Christchurch, the New Zealand government has BANNED all semi-automatic weapons.…
# 2019-03-18 20:53:21
# RT @VOANews: An emotional Haka was performed on Saturday, March 16, outside the Al Noor mosque in Christchurch, where 50 died in Friday's a…
# 2019-03-17 07:26:31
# @StopFakeCases @memorable_90s Jayaprakash #Legend
# 2019-03-17 04:47:41
# RT @Mahmudullah30: Alhamdulillah! Last night we got back to home safe &amp; sound. May the almighty Allah gives strength to those who lost thei…
# 2019-03-16 11:16:22
# RT @PeteButtigieg: Some words for South Bend's Muslim community. https://t.co/CyLZOrah7b
# 2019-03-16 11:15:34
# RT @Freedland: This isn’t about lone killers and deranged individuals. This is a terrorist movement of white supremacism that draws strengt…
# 2019-03-16 06:11:07
# RT @philipdalidakis: An open offer to any Muslim man, woman or child. If you are fearful about walking through the gates of your mosque, le…
# 2019-03-16 06:10:57
# RT @DennisCricket_: I'm ashamed that this is on Australian Government letterhead.
#
# That can only happen because enough Australians voted f…
# 2019-03-16 04:13:07
# @arefinforbd #জ্ঞানীমানুষ
# 2019-03-15 22:37:39
# RT @MominulHaque68: Terrifying to be so close to this tragic. May Allah give jannah to my innocent brothers. Wish we could all live peace i…
# 2019-03-15 21:32:04
# RT @Angelo69Mathews: Schocked to hear about the new Zealand massacre.Thoughts and prayers with all those who are affected,relieved to hear…
# 2019-03-15 21:31:33
# RT @MClarke23: Horrific news out of Christchurch! Absolutely devastating. Thoughts and prayers go out to all affected at this extremely sad…
# 2019-03-15 12:12:33
# RT @ScottMorrisonMP: The remarks by Senator Fraser Anning blaming the murderous attacks by a violent, right-wing, extremist terrorist in Ne…
# 2019-03-15 12:12:12
# RT @icelandcricket: Icelanders are praying for our Muslim brothers in Christchurch. https://t.co/imENHIoLb1
# 2019-03-15 12:07:21
# RT @Uz_Khawaja: So saddened about the attacks in Christchurch today. My heart and duahs go out to all the victims and their families ❤️
# 2019-03-15 12:07:06
# RT @AlanahEriksen: @rodemmerson https://t.co/68AyOCt8ff
# 2019-03-15 12:06:33
# RT @joeburns441: My thoughts are with the people in Christchurch and Muslims around the world. @fraser_anning is an embarrassment to QLD &amp;…

# %%
tweet_list = []
for tweet in tweets:
    tweet_list.append(tweet._json)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(tweet_list)

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
df.set_index('created_at', inplace=True)

# %%
df.dtypes
# Out:
# contributors                  object
# coordinates                   object
# entities                      object
# extended_entities             object
# favorite_count                 int64
# favorited                       bool
# geo                           object
# id                             int64
# id_str                        object
# in_reply_to_screen_name       object
# in_reply_to_status_id        float64
# in_reply_to_status_id_str     object
# in_reply_to_user_id          float64
# in_reply_to_user_id_str       object
# is_quote_status                 bool
# lang                          object
# place                         object
# possibly_sensitive            object
# quoted_status                 object
# quoted_status_id             float64
# quoted_status_id_str          object
# retweet_count                  int64
# retweeted                       bool
# retweeted_status              object
# source                        object
# text                          object
# truncated                       bool
# user                          object
# dtype: object

# %%
y = df['id'].resample('D').sum()
y.plot(figsize=(15, 6));

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
def check_tweets(twitter_handle):
    json_str = []
    for status in tweepy.Cursor(api.user_timeline,id=twitter_handle).items(200):
        json_str.append(status._json)
    
    df = pd.DataFrame(json_str)
    df['created_at'] = pd.to_datetime(df['created_at'])
    df.set_index('created_at', inplace=True)
    
    y = df['id'].resample('D').count()
    y.plot(figsize=(15, 6))
    plt.show();

# %%
def check_tweets_wordcloud(twitter_handle):
    json_str = []
    for status in tweepy.Cursor(api.user_timeline,id=twitter_handle).items(200):
        json_str.append(status._json)
    
    df = pd.DataFrame(json_str)
    
#     text = df.text.values
    
    text = ','.join([x for x in df.text.values])
    blob = TextBlob(text)
    text = blob.noun_phrases
    
    wordcloud = WordCloud(
        width = 3000
        , height = 2000
        , background_color = 'black'
        , stopwords = STOPWORDS
    ).generate(str(text))
    
    fig = plt.figure(figsize = (40, 30), facecolor = 'k', edgecolor = 'k')
    plt.imshow(wordcloud, interpolation = 'bilinear')
    plt.axis('off')
    plt.show();

# %%
check_tweets_wordcloud('sanjaymanjrekar')

# %%
from textblob import TextBlob

text = ','.join([x for x in df.text.values])
blob = TextBlob(text)
text = blob.noun_phrases
    
wordcloud = WordCloud(
    width = 3000
    , height = 2000
    , background_color = 'black'
    , stopwords = STOPWORDS
).generate(str(text))

fig = plt.figure(figsize = (40, 30), facecolor = 'k', edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show();

# %% [markdown]
# You can create a tweet as follows:

# %%
# create a tweet:
tweet = api.update_status('Test: Made with Tweepy')

# %% [markdown]
# (Nb. Don't abuse this feature! If you try to generate a zillion tweets in a loop, Twitter will ban youur account.)

# %% [markdown]
# Tweets can be deleted by reference to their `id_str` attribute:

# %%
# delete a tweet:
status = api.destroy_status(tweet.id_str)

# %% [markdown]
# You can follow a Tweeter:

# %%
# follow:
api.create_friendship('@YouTube')

# %% [markdown]
# or unfollow:

# %%
# unfollow:
api.destroy_friendship('@YouTube')

# %% [markdown]
# >
# >
# >
# >
# >

# %% [markdown]
# >
# >

# %% [markdown]
# ---
#
#
#
# ---
#
# > > > > > > > > > © 2019 Data Science Institute of Australia
#
#
#
# ---
#
#
#
# ---
